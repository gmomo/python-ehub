# %%
from html.parser import HTMLParser  
from urllib.request import urlopen  
from urllib import parse

# We are going to create a class called LinkParser that inherits some
# methods from HTMLParser which is why it is passed into the definition
class LinkParser(HTMLParser):

    # This is a function that HTMLParser normally has
    # but we are adding some functionality to it
    def handle_starttag(self, tag, attrs):
        # We are looking for the begining of a link. Links normally look
        # like <a href="www.someurl.com"></a>
        if tag == 'a':
            for (key, value) in attrs:
                if key == 'href':
                    # We are grabbing the new URL. We are also adding the
                    # base URL to it. For example:
                    # www.netinstructions.com is the base and
                    # somepage.html is the new URL (a relative URL)
                    #
                    # We combine a relative URL with the base URL to create
                    # an absolute URL like:
                    # www.netinstructions.com/somepage.html
                    newUrl = parse.urljoin(self.baseUrl, value)
                    # And add it to our colection of links:
                    self.links = self.links + [newUrl]

    # This is a new function that we are creating to get links
    # that our spider() function will call
    def getLinks(self, url):
        self.links = []
        # Remember the base URL which will be important when creating
        # absolute URLs
        self.baseUrl = url
        # Use the urlopen function from the standard Python 3 library
        response = urlopen(url)
        # Make sure that we are looking at HTML and not other things that
        # are floating around on the internet (such as
        # JavaScript files, CSS, or .PDFs for example)
        if response.getheader('Content-Type')=='text/html':
            htmlBytes = response.read()
            # Note that feed() handles Strings well, but not bytes
            # (A change from Python 2.x to Python 3.x)
            htmlString = htmlBytes.decode("utf-8")
            self.feed(htmlString)
            return htmlString, self.links
        else:
            return "",[]

# And finally here is our spider. It takes in an URL, a word to find,
# and the number of pages to search through before giving up
def spider(url, word, maxPages):  
    pagesToVisit = [url]
    numberVisited = 0
    foundWord = False
    # The main loop. Create a LinkParser and get all the links on the page.
    # Also search the page for the word or string
    # In our getLinks function we return the web page
    # (this is useful for searching for the word)
    # and we return a set of links from that web page
    # (this is useful for where to go next)
    while numberVisited < maxPages and pagesToVisit != [] and not foundWord:
        numberVisited = numberVisited +1
        # Start from the beginning of our collection of pages to visit:
        url = pagesToVisit[0]
        pagesToVisit = pagesToVisit[1:]
        try:
            print(numberVisited, "Visiting:", url)
            parser = LinkParser()
            data, links = parser.getLinks(url)
            if data.find(word)>-1:
                foundWord = True
                # Add the pages that we visited to the end of our collection
                # of pages to visit:
                pagesToVisit = pagesToVisit + links
                print(" **Success!**")
        except:
            print(" **Failed!**")
    if foundWord:
        print("The word", word, "was found at", url)
    else:
        print("Word never found")

# %%
spider("http://www.swissquant.com/en/775/Open-Positions.htm","Specialist",200)
# Out:
# 1 Visiting: http://www.swissquant.com/en/775/Open-Positions.htm
# Word never found

# %%
from bs4 import BeautifulSoup
import requests
import hickle as hkl
import numpy as np
import pandas as pd
import re

# %%
url_to_scrape = 'http://www.swissquant.com/en/775/Open-Positions.htm'
r = requests.get(url_to_scrape)
 
soup = BeautifulSoup(r.text, 'lxml')

# %%
#print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="noodp,noydir" name="robots"/>
#   <base href="http://www.swissquant.com/data/"/>
#   <!-- this page was produced using the content management system (CMS) PC3 by The Toolpark Corporation AG (www.toolpark.com). License issued to SWISSQUANT -->
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/reset/all.css?m=1389010974" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/common/all.css?m=1411022264" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/design/all.Tablet.css?m=1411022264" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/navigation/all.css?m=1411022271" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/utils-lightbox/all.css?m=1411022272" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/brick-Image/all.css?m=1411022260" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/content/all.Tablet.css?m=1427967875" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/surf-n-edit/all.css?m=1411022272" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/brick-Box/all.css?m=1411022261" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/bricks/all.css?m=1411022263" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/brick-DynamicList/all.css?m=1411022261" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/forms/all.css?m=1411562475" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/styles/en/Hauptstil/utils-ajaxloader/all.css?m=1411022272" rel="stylesheet" type="text/css"/>
#   <script src="http://www.swissquant.com/data/scripts/prototype.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/common.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/form.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/inputcontrol.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/widget.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/popup.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/tweener.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/pc3lib/almond.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/pc3lib/jquery-1.8.3.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/pc3lib/jquery-1.8.3.export.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/pc3/fallback/layout.js?v=13" type="text/javascript">
#   </script>
#   <script src="http://www.swissquant.com/data/scripts/pc3/ajax/content.js?v=13" type="text/javascript">
#   </script>
#   <script src="docs/en/1318/html5shiv.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    jQuery(document).ready(function($) {
#
#     $('#body-wrapper > header .job-offers a').hover(function(){
# 		$('.job-offers').css('background-position','0px -115px');
# 	}, function(){
#         $('.job-offers').css('background-position','0px 0px');
# 	});
#
# });
#   </script>
#   <script type="text/javascript">
#    if ( navigator.cookieEnabled ) document.cookie = "cookiecheck=1; path=/;";
# var xEncryptionKey = 'jd883hcjs433sdfse3d';
#   </script>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="http://www.swissquant.com/data/docs/en/1387/Helvetica.css" rel="stylesheet" type="text/css"/>
#   <link href="http://www.swissquant.com/data/docs/en/1349/print.css" rel="stylesheet" type="text/css"/>
#   <meta content="width=1265" name="viewport"/>
#   <title>
#    swissQuant - Open Positions
#   </title>
#  </head>
#  <body class="pc3body body" onload="pc3PageOnLoad()">
#   <script type="text/javascript">
#    pc3PopupDesignData["lightbox1"] = {"ajaxContentId":"brick","placeholders":null,"positionChilds":"relative","behaviour":"attachedToEndposition","open":{"trigger":"click","duration":"0.3","effect":"fadeIn","animationType":"visible"},"close":{"duration":"0.3","effect":"fadeOut"},"background":{"enabled":"1","opacity":"60"},"shadow":{"enabled":"1","color":"#000000","blurRadius":"5","opacity":"35","marginTop":"-5","marginRight":"8","marginBottom":"8","marginLeft":"2","cornerSize":"21","imageTop":"docs\/en\/1020\/Schatten-Oben.png","imageRight":"docs\/en\/1021\/Schatten-Rechts.png","imageBottom":"docs\/en\/1022\/Schatten-Unten.png","imageLeft":"docs\/en\/1019\/Schatten-Links.png"}};
#   </script>
#   <div class="pc3popupdesign lightbox1" id="lightbox1">
#    <div class="zoom-section content">
#     <div class="zoom-body">
#      <a class="close" href="javascript: void(0);" onclick="pc3Widget.closePopup(this);">
#       Close
#      </a>
#      <div id="brick_onRequestContent" style="display:none">
#       <div>
#        <div style="top:50%; left:50%; margin-top:-7px; margin-left:-64px; position:absolute;">
#         <img alt="Ajax Loader" height="15" src="docs/en/1027/Ajax-Loader.gif" width="128"/>
#        </div>
#       </div>
#      </div>
#      <div id="brick_onErrorContent" style="display:none">
#       <p>
#        Error
#       </p>
#      </div>
#      <div id="brick">
#       <!-- AjaxContent brick start -->
#       <!-- AjaxContent brick end -->
#      </div>
#      <script type="text/javascript">
#       PC3.require('pc3/ajax/content').create("brick",null,null,null,null,"brick");
#      </script>
#     </div>
#    </div>
#   </div>
#   <div id="body-wrapper">
#    <a class="anchor" name="top">
#    </a>
#    <header class="clearfix">
#     <div class="job-offers">
#      <a href="http://www.swissquant.com/en/689/job-offers.htm">
#       Job offers
#      </a>
#     </div>
#     <nav id="navigation-meta">
#      <ul>
#       <li>
#        <a href="http://www.swissquant.com/en/357/Homepage.htm">
#         Home
#        </a>
#       </li>
#       <li>
#        <a href="http://www.swissquant.com/en/353/Contact.htm">
#         Contact
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <nav id="navigation-language">
#      <ul class="pc3layout auto-layout">
#       <li>
#        <a href="http://www.swissquant.com/de/775/Offene-Stellen.htm">
#         Deutsch
#        </a>
#       </li>
#       <li class="selected">
#        <a href="http://www.swissquant.com/en/775/Open-Positions.htm">
#         English
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <a class="anchor" name="topnav">
#     </a>
#     <nav id="navigation-top">
#      <ul>
#       <li>
#        <a href="http://www.swissquant.com/en/668/Technologie.htm">
#         Technology
#        </a>
#       </li>
#       <li>
#        <a href="http://www.swissquant.com/en/546/Research.htm">
#         Research
#        </a>
#       </li>
#       <li>
#        <a href="http://www.swissquant.com/en/718/Kunden.htm">
#         Clients
#        </a>
#       </li>
#       <li>
#        <a href="http://www.swissquant.com/en/685/Company.htm">
#         Company
#        </a>
#       </li>
#       <li class="selected">
#        <a href="http://www.swissquant.com/en/689/Career.htm">
#         Career
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <div class="logo">
#      <a href="http://www.swissquant.com/en/302/Home.htm">
#       <img alt="logo" height="50" src="docs/en/1342/logo.png" width="199"/>
#       <br/>
#      </a>
#      <p>
#       Mastering Complexity
#      </p>
#     </div>
#    </header>
#    <section class="pc3layout" id="main">
#     <div class="main-navigation">
#      <a class="anchor" name="subnav">
#      </a>
#      <div id="site-functions">
#       <ul class="pc3layout auto-layout">
#        <li>
#         <a class="search" href="http://www.swissquant.com/en/693/Suche.htm">
#          Suchen
#         </a>
#        </li>
#       </ul>
#      </div>
#      <nav id="navigation-main">
#       <ul>
#        <li class="selected">
#         <a href="http://www.swissquant.com/en/775/Open-Positions.htm">
#          Open Positions
#         </a>
#        </li>
#        <li>
#         <a href="https://shared02.toolpark.com/swissquant/en/776/Registration.htm">
#          Registration
#         </a>
#        </li>
#        <li>
#         <a href="http://www.swissquant.com/en/809/Career-Events.htm">
#          Career Events
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <div class="content">
#       <div class="main-col">
#        <div class="box1 isFirst isLast" id="pc8788140031382540065">
#         <div class="box-body">
#          <div class="bricks isFirst isLast">
#           <div class="image isFirst">
#            <img alt="candidate2_17220214" height="283" src="docs/en/1681/candidate2-17220214.jpg?variant=3638" width="260"/>
#           </div>
#           <h3 class="blue">
#            Stay connected.
#           </h3>
#           <em>
#            swissQuant also seeks in the future passionate Quants and Developers.
#           </em>
#           <a class="internal isLast" href="https://shared02.toolpark.com/swissquant/en/776/Registration.htm">
#            Register today for a future career opportunity
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div>
#      <div>
#      </div>
#     </div>
#     <div class="main-content content">
#      <div class="clearfix" id="logo-print">
#       <img alt="L_sQ_mClaim_RGB" height="150" src="docs/en/1391/L-sQ-mClaim-RGB.jpg?variant=4682" width="200"/>
#      </div>
#      <a class="anchor" name="content">
#      </a>
#      <article>
#       <header>
#        <hgroup>
#         <a class="internal" href="https://shared02.toolpark.com/swissquant/en/776/Registration.htm">
#          Sign in
#         </a>
#         <h1>
#          Open Positions
#         </h1>
#        </hgroup>
#       </header>
#       <div class="main-col">
#        <img alt="people1-16120673-RGB" height="130" src="docs/en/1549/people1-16120673-RGB.jpg" width="660"/>
#        <em style="display:block; margin-top:20px;">
#         If you thrive in dynamic and challenging environments, swissQuant Group may be for you. Check the job openings posted to see how you can use your competencies to take an active part in the development of a complete new range of scientific methods and tools shaping current and future businesses.
#        </em>
#        <div id="jobResults_onRequestContent" style="display:none">
#         <div class="ajax-loader">
#          <img alt="Ajax Loader" class="ajax-loader" height="15" src="docs/en/1027/Ajax-Loader.gif" width="128"/>
#         </div>
#        </div>
#        <div id="jobResults">
#         <!-- AjaxContent jobResults start -->
#         <form action="http://www.swissquant.com/en/775/Open-Positions.htm" alt="http://www.swissquant.com/en/775/Open-Positions.htm" enctype="multipart/form-data" id="pc358e388362db32" method="post" onsubmit="return PC3.require('pc3/ajax/content').requestPost(event,this,&quot;jobResults&quot;,this.alt);">
#          <div class="box1">
#           <div class="box-body">
#            <fieldset style="padding:0px; margin:0px;">
#             <div class="form-field">
#              <table cellpadding="0" cellspacing="0" width="100%">
#               <tr>
#                <td style="padding-right:20px;">
#                 <input class="textfield" name="Search" placeholder="Keyword search" style="width:200px;" type="text" value=""/>
#                </td>
#                <td>
#                 <input name="Category_checkInput" type="hidden" value="true"/>
#                 <select class="pc3-select" name="Category" onchange="pc3SubmitForm(this.form,false);" size="1" style="width:280px;">
#                  <option class="overview" selected="" value="">
#                   All categories
#                  </option>
#                  <option value="22280">
#                   Master Theses and Internships
#                  </option>
#                  <option value="22281">
#                   Junior Quant Engineer
#                  </option>
#                  <option value="22282">
#                   Quant Engineer / Developer
#                  </option>
#                  <option value="22286">
#                   Senior Quant Engineer / Quant Leader
#                  </option>
#                  <option value="22284">
#                   For Non Quants
#                  </option>
#                 </select>
#                </td>
#                <td>
#                 <input class="button" onclick='return pc3SubmitLink("pc358e388362db32",null,1);' type="submit" value="Search"/>
#                </td>
#               </tr>
#              </table>
#             </div>
#            </fieldset>
#           </div>
#          </div>
#         </form>
#         <section class="dynamiclist clearfix">
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=27496">
#            <h3>
#             Quantitative Research Engineer - Optimization Specialist
#            </h3>
#            <p class="isLast">
#             100%, Zürich, starting immediately
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=27592">
#            <h3>
#             Master Thesis
#            </h3>
#            <p class="isLast">
#             100%, Zurich, up to 6 months, starting immediately
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=27581">
#            <h3>
#             Technical Project Manager
#            </h3>
#            <p class="isLast">
#             100%, Zürich City, Beginn verhandelbar
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=20148">
#            <h3>
#             Software Development Internship
#            </h3>
#            <p class="isLast">
#             100%, Zürich, 6 months, starting immediately or negotiable
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=27762">
#            <h3>
#             Sales and Relationship Manager
#            </h3>
#            <p class="isLast">
#             100%, Zurich City, immediately or by agreement
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=19933">
#            <h3>
#             Java Software Developer
#            </h3>
#            <p class="isLast">
#             100%, Zürich, starting immediately, negotiable
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=27949">
#            <h3>
#             Quant / Support / DevOps Engineers Maintenance &amp; Services Team
#            </h3>
#            <p class="isLast">
#             100%, Zurich City, permanent, starting immediately
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=26312">
#            <h3>
#             Quant Internship Private Banking Technologies
#            </h3>
#            <p class="isLast">
#             100%, Zürich City, 6 months, starting immediately
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=21799">
#            <h3>
#             Quantitative Research Internship
#            </h3>
#            <p class="isLast">
#             100%, Zürich, 6 months, starting immediately
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#          <article class="clearfix">
#           <a class="clearfix" href="http://www.swissquant.com/en/775/Open-Positions.htm?Job=28411">
#            <h3>
#             Project Manager / Business Analyst
#            </h3>
#            <p class="isLast">
#             100%, Zürich, Beginn verhandelbar
#            </p>
#            <span>
#            </span>
#           </a>
#          </article>
#         </section>
#         <!-- AjaxContent jobResults end -->
#        </div>
#        <script type="text/javascript">
#         PC3.require('pc3/ajax/content').create("jobResults",null,null,null,null,"jobResults");
#        </script>
#       </div>
#      </article>
#     </div>
#    </section>
#    <footer>
#     <div id="page-functions">
#      <ul>
#       <li>
#        <a class="print" href="http://www.swissquant.com/en/775/Open-Positions.htm" onclick="window.print();">
#         Print version
#        </a>
#       </li>
#       <li>
#        <a class="top" href="http://www.swissquant.com/en/775/Open-Positions.htm#top">
#         Top
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div id="address-footer">
#      <strong class="isFirst isLast">
#       swissQuant Group AG
#      </strong>
#      <p class="isFirst">
#       Kuttelgasse 7
#       <br/>
#       CH-8001 Zurich
#       <br/>
#       +41 43 244 75 85
#      </p>
#      <a href="javascript: void(0)" onclick="this.href=dcm('AwpeV3MbFAMAR0JGEgoSXQZcCQ==');">
#       <script>
#        dcw('AwpeV3MbFAMAR0JGEgoSXQZcCQ==')
#       </script>
#      </a>
#     </div>
#     <nav id="navigation-footer">
#      <ul class="pc3layout auto-layout">
#       <li>
#        <a href="http://www.swissquant.com/en/687/Disclaimer.htm">
#         Disclaimer
#        </a>
#       </li>
#       <li>
#        <a href="http://www.swissquant.com/en/680/Imprint-Webmaster-Liability-Webdesign-CMS-Content-Management-System.htm">
#         Imprint
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </footer>
#   </div>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', "UA-20615940-1"]);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#   </script>
#   <form action="http://www.swissquant.com/?pc3FileUpload=1" enctype="multipart/form-data" id="pc3FileUploadForm" method="POST" style="display:none">
#    <input name="id"/>
#    <input name="types"/>
#   </form>
#   <script type="text/javascript">
#    pc3.InputControl.init();
#
# var pc3PageOnLoad = function(){
# pc3WidgetInit();
# PC3.require('pc3/fallback/layout')();;
# pc3SetPlaceholders();
# };
#   </script>
#  </body>
# </html>

# %%
for link in soup.find_all('a'):
    if 'Career' in link:
        print(link.get('href'))
# Out:
# http://www.swissquant.com/en/689/Career.htm

# %%
positions=[]
for name in soup.find_all('h3'):
    positions.append(name.text)

# %%
positions
# Out:
# ['Stay connected.',
#  'Quantitative Research Engineer - Optimization Specialist',
#  'Master Thesis',
#  'Technical Project Manager',
#  'Software Development Internship',
#  'Sales and Relationship Manager',
#  'Java Software Developer',
#  'Quant / Support / DevOps Engineers Maintenance & Services Team',
#  'Quant Internship Private Banking Technologies',
#  'Quantitative Research Internship',
#  'Project Manager / Business Analyst']

# %%
url_to_scrape = 'http://www.swissquant.com/en/775/Open-Positions.htm'
r = requests.get(url_to_scrape)
 
soup = BeautifulSoup(r.text, 'lxml')

#testing=pd.read_hdf(r'T:\Job.h5',url_to_scrape.split('/')[2])

positions=dict()
for name in soup.find_all('h3'):
    if url_to_scrape in positions:
        if name.text not in positions[url_to_scrape]:
            positions[url_to_scrape].add(name.text)
                
    else:
        positions[url_to_scrape]=set()
'''        
hdf=pd.HDFStore(r'T:\Job.h5')
save= pd.DataFrame.from_dict(data=positions, orient='index')
#save.columns=range(0,len(positions[url_to_scrape]))
hdf.put(url_to_scrape.split('/')[2], save)
hdf.close() 
'''
# Out:
# "        \nhdf=pd.HDFStore(r'T:\\Job.h5')\nsave= pd.DataFrame.from_dict(data=positions, orient='index')\n#save.columns=range(0,len(positions[url_to_scrape]))\nhdf.put(url_to_scrape.split('/')[2], save)\nhdf.close() \n"

# %%
testing.loc[url_to_scrape].str.contains('Master Thesis').sum()
# Out:
# 1

# %%
positions.keys()
# Out:
# dict_keys(['https://apply.refline.ch/845721/search.html?segment=postDoctoralCandidate', 'http://www.swissquant.com/en/775/Open-Positions.htm'])

# %%
url_to_scrape = 'https://apply.refline.ch/845721/search.html?segment=postDoctoralCandidate'
r = requests.get(url_to_scrape)
 
soup = BeautifulSoup(r.text, 'lxml')
for name in soup.find_all('a'):
    if url_to_scrape in positions:
        if name.text not in positions[url_to_scrape]:
            positions[url_to_scrape].add(name.text)
                
    else:
        positions[url_to_scrape]=set()

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="de">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    ETH Zürich
#   </title>
#   <meta content="initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=0;" name="viewport"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <link href="https://cdn.refline.ch/3.0.0/eth/b/browser.min.css" rel="stylesheet"/>
#   <script src="https://cdn.refline.ch/3.0.0/sbrowser/jquery.min.js">
#   </script>
#   <script src="https://cdn.refline.ch/3.0.0/sbrowser/sbrowser.min.js">
#   </script>
#   <script src="https://cdn.refline.ch/3.0.0/eth/b/browser.js">
#   </script>
#  </head>
#  <body>
#   <a name="toplink">
#   </a>
#   <div class="container searchContainer">
#    <div class="header">
#     <div class="logo">
#      <a class="logoLink" href="http://www.ethz.ch" target="_blank">
#      </a>
#     </div>
#     <div class="right">
#      <ul class="langs">
#       <li>
#        <a href="?lang=de&amp;segment=postDoctoralCandidate">
#         Deutsch
#        </a>
#       </li>
#       <li>
#        <a href="?lang=en&amp;segment=postDoctoralCandidate">
#         English
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="clearer">
#     </div>
#    </div>
#    <div class="searchContent" id="content">
#     <form action="https://apply.refline.ch/845721/search.html" class="form" enctype="multipart/form-data" id="simple" method="post" name="simple">
#      <div class="searchHeader searchHeaderImage02">
#      </div>
#      <div class="searchTopContent">
#       <div class="title">
#        Stellenangebote der ETH Zürich
#       </div>
#       <div class="text">
#        Die ETH Zürich ist der Studien-, Forschungs- und Arbeitsplatz von rund 30 000 Menschen aus über 110 Ländern. Ihren Mitarbeitenden gegenüber versteht sich die ETH Zürich als verantwortungsbewusste Arbeitgeberin mit fortschrittlichen Anstellungs- und Arbeitsbedingungen und einem breiten Weiterbildungsangebot. Informieren Sie sich hier über die aktuellen Stellenangebote.
#       </div>
#      </div>
#      <div class="searchBGSpacer">
#      </div>
#      <div class="searchFilterContent">
#       <div class="searchFilterLeft">
#        <div class="">
#         <b>
#          Filter:
#         </b>
#         Klicken Sie auf einen Link um die Suche einzugrenzen.
#        </div>
#        <div class="searchFilterWrapper">
#         <div class="searchFilterColumn01">
#          <div class="subtitle">
#           ETH Zürich
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?all=1">
#            Alle Stellen
#           </a>
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?parttime=1">
#            Teilzeit
#           </a>
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?fulltime=1">
#            Vollzeit
#           </a>
#          </div>
#          <div class="subtitle">
#           Berufsbildung
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?internship=1">
#            Lehrstellen
#           </a>
#          </div>
#         </div>
#         <div class="searchFilterColumn02">
#          <div class="subtitle">
#           Forschung und Lehre
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?segment=practical">
#            Hilfsassistierende / Praktika
#           </a>
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?segment=doctoralCandidate">
#            Doktorierende
#           </a>
#          </div>
#          <div>
#           <a class="active" href="https://apply.refline.ch/845721/search.html?segment=postDoctoralCandidate">
#            Postdoktorierende
#           </a>
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?segment=scientificAssistant">
#            Wissenschaftliche Mitarbeitende
#           </a>
#          </div>
#          <div>
#           <a href="https://www.ethz.ch/de/die-eth-zuerich/arbeiten-lehren-forschen/faculty-affairs/ausgeschriebene-professuren.html" target="_blank">
#            Professuren
#           </a>
#          </div>
#         </div>
#         <div class="searchFilterColumn03">
#          <div class="subtitle">
#           Support
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?businessUnit=administration">
#            Administration
#           </a>
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?businessUnit=technic-labor">
#            Technik / Labor
#           </a>
#          </div>
#          <div>
#           <a href="https://apply.refline.ch/845721/search.html?businessUnit=it">
#            Informatik
#           </a>
#          </div>
#         </div>
#         <div class="clearer">
#         </div>
#        </div>
#       </div>
#       <div class="searchFilterRight">
#        <div class="furtherOffersHeader">
#         Weiterführende Links
#        </div>
#        <div class="searchJobmail">
#         <span class="">
#          Sie wollen regelmässig per Mail über neue Stellen informiert werden?
#         </span>
#         <nobr>
#          <a href="https://apply.refline.ch/845721/jobmail.html" target="_top">
#           Jobmail abonnieren
#          </a>
#         </nobr>
#        </div>
#        <div class="ethLinks">
#         <div class="furtherOffersHeader">
#          Stellenangebote ETH-Bereich
#         </div>
#         <a class="offerslink" href="http://emploi.epfl.ch/" target="_blank">
#          EPF Lausanne
#         </a>
#         |
#         <a class="offerslink" href="https://www.psi.ch/pa/stellenangebote#!/" target="_blank">
#          Paul Scherrer Institut
#         </a>
#         |
#         <a class="offerslink" href="https://apply.refline.ch/673277/search.html" target="_blank">
#          Eawag
#         </a>
#         |
#         <a class="offerslink" href="https://apply.refline.ch/673276/search.html" target="_blank">
#          Empa
#         </a>
#         |
#         <a class="offerslink" href="https://apply.refline.ch/273855/search.html" target="_blank">
#          WSL
#         </a>
#         |
#         <a class="offerslink" href="http://www.ethrat.ch/de/jobs" target="_blank">
#          ETH-Rat
#         </a>
#        </div>
#        <div class="otherLinks">
#         <div class="furtherOffersHeader">
#          Andere Anbieter
#         </div>
#         <a class="offerslink" href="http://www.eth-gethired.ch/" target="_blank">
#          ETH get hired
#         </a>
#         |
#         <a class="offerslink" href="http://www.jobservices.ethz.ch/" target="_blank">
#          ETH Alumni Job Services
#         </a>
#         |
#         <a class="offerslink" href="http://www.switch.ch/de/about/jobs/" target="_blank">
#          SWITCH
#         </a>
#         |
#         <a class="offerslink" href="http://www.jobs.uzh.ch/" target="_blank">
#          Universität Zürich
#         </a>
#        </div>
#       </div>
#       <div class="clearer">
#       </div>
#      </div>
#      <div class="searchBGSpacer">
#      </div>
#      <div class="searchIsResult">
#       <table class="jquery-tablesorter">
#        <thead>
#         <tr>
#          <th class="position">
#           Stelle (ETH)
#          </th>
#          <th class="workload">
#           Pensum
#          </th>
#          <th class="department">
#           Institution
#          </th>
#          <th class="workplace">
#           Arbeitsort
#          </th>
#          <th class="published">
#           Veröffentlicht
#          </th>
#         </tr>
#        </thead>
#        <tbody>
#         <tr class="even">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5290/pub/1/index.html" target="_blank">
#            Postdoctoral Fellow in the area of Data-Driven Nonlinear Modeling and System-Identification for complex mechanical vibrations
#           </a>
#          </td>
#          <td class="workload">
#           100%
#          </td>
#          <td class="department">
#           Institute of Mechanical Systems
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           04.04.2017
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5291/pub/1/index.html" target="_blank">
#            2 PostDoc positions in Research on Higher Education and/or Quantitative Studies of Science and/or Peer Review Research (80-100%)
#           </a>
#          </td>
#          <td class="workload">
#           80% - 100%
#          </td>
#          <td class="department">
#           Social Psychology and Research on Higher Education
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           04.04.2017
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5284/pub/1/index.html" target="_blank">
#            Post-Doc in Radiopharmacy and preclinical Imaging
#           </a>
#          </td>
#          <td class="workload">
#           100%
#          </td>
#          <td class="department">
#           Institute of Pharmaceutical Sciences
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           30.03.2017
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5267/pub/1/index.html" target="_blank">
#            Post-doc in Lymphatic Imaging of the Central Nervous System
#           </a>
#          </td>
#          <td class="workload">
#           100%
#          </td>
#          <td class="department">
#           Institute of Pharmaceutical Sciences
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           16.03.2017
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5257/pub/1/index.html" target="_blank">
#            Postdoc in Agro-ecology (80-100%, 2 years)
#           </a>
#          </td>
#          <td class="workload">
#           80% - 100%
#          </td>
#          <td class="department">
#           Institute of Agricultural Sciences
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           13.03.2017
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5232/pub/1/index.html" target="_blank">
#            Postdoctoral fellow in Macromolecular Engineering of Responsive Hydrogels
#           </a>
#          </td>
#          <td class="workload">
#           100%
#          </td>
#          <td class="department">
#           Department of Mechanical and Process Engineering
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           22.02.2017
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5228/pub/1/index.html" target="_blank">
#            Postdoctoral Researcher in the area of blockchain technology
#           </a>
#          </td>
#          <td class="workload">
#           100%
#          </td>
#          <td class="department">
#           Department of Humanities, Social and Political Sciences
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           17.02.2017
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5207/pub/1/index.html" target="_blank">
#            Postdoctoral position in Big Data and Data Science
#           </a>
#          </td>
#          <td class="workload">
#           100%
#          </td>
#          <td class="department">
#           Department of Humanities, Social and Political Sciences
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           09.02.2017
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5191/pub/1/index.html" target="_blank">
#            Postdoctoral Researcher in Mesoscopic Systems
#           </a>
#          </td>
#          <td class="workload">
#           100%
#          </td>
#          <td class="department">
#           The Laboratory for Mesoscopic Systems (PSI)
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           03.02.2017
#          </td>
#         </tr>
#         <tr class="odd">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/4946/pub/6/index.html" target="_blank">
#            Postdoctoral Researcher “Urban materials and their impacts on the urban climate”
#           </a>
#          </td>
#          <td class="workload">
#           100%
#          </td>
#          <td class="department">
#           Chair of Building Physics
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           03.02.2017
#          </td>
#         </tr>
#         <tr class="even">
#          <td class="position">
#           <a href="https://apply.refline.ch/845721/5107/pub/1/index.html" target="_blank">
#            Postdoctoral position in the field of Whole Building Energy Data Analysis, Systems Modeling and Simulation
#           </a>
#          </td>
#          <td class="workload">
#           100%
#          </td>
#          <td class="department">
#           Institut für Technologie in der Architektur
#          </td>
#          <td class="workplace">
#           Region Zürich
#          </td>
#          <td class="published">
#           23.12.2016
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <div id="resultLenght">
#        <b>
#         Es liegen
#         <span>
#          11
#         </span>
#         Angebote vor.
#        </b>
#       </div>
#      </div>
#     </form>
#     <script>
#      /* jquery tablesorter */
#   var myTextExtraction = function(node) {
#       // extract data from markup and return it
#       t = $(node).text();
#       return t.toLowerCase();
#   };
#
#   $.tablesorter.addParser({
#       id: "germanDate",
#       is: function (s) {
#           return /\d{1,2}[.]\d{1,2}[.]\d{2,4}/.test(s);
#       },
#       format: function (s, table) {
#           var c = table.config;
#           if (c.dateFormat == "german") {
#               s = s.replace(/(\d{1,2})[.](\d{1,2})[.](\d{2,4})/, "$3-$2-$1");
#           }
#           return s; // warning this works out only for YYYY-MM-DD dates!!!
#       },
#       type: "text"
#   });
#
#   $(document).ready(function() {
#     $(".jquery-tablesorter").tablesorter({
#       sortList: [[4,1]],
#       cssAsc: 'jquery-tablesorter-thUp',
#       cssDesc: 'jquery-tablesorter-thDown',
#       cssHeader: 'jquery-tablesorter-th',
#       textExtraction: myTextExtraction,
#       dateFormat: 'german'
#     });
#   });
#     </script>
#    </div>
#   </div>
#  </body>
# </html>
