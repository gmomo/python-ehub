# %%
from pyomo.core import *
from pyomo.opt import SolverFactory, SolverManagerFactory
import pyomo.environ
import pandas as pd
import numpy as np
from itertools import compress
import xarray as xr

# %%
from IPython.core.display import HTML
HTML("<style>.container { width:80% !important; }</style>")
# Out:
# <style>.container { width:80% !important; }</style>

# %%
class InputData:
    
    #----------------------------------------------------------------------
    
    def __init__(self, ExcelPath, demands='Demand data',solar='Solar data', tech='Technology', gen='General'):
        self.path = ExcelPath
        self.DemandSheet = demands
        self.SolarSheet = solar
        self.TechSheet = tech
        self.GeneralSheet = gen
        
        self.TechOutputs = None
        self.Technologies = None
        self.DemandData = None
        self.StorageData = None
        self.numberofhubs = None
        self.numberofdemands = None
        
        self.Initialize()
        
    def Initialize(self):
        self.Hubs()
        self.Demanddata()
        self.TechParameters()
        self.TechOutput()
        self.Storage()        
        
    def TechParameters(self):
        Technologies=pd.read_excel(self.path,sheetname=self.TechSheet, skiprows=1, index_col=0, skip_footer=38) #technology characteristics
        Technologies=Technologies.dropna(axis=1, how='all') #technology characteristics
        Technologies=Technologies.fillna(0) #technology characteristics
        dd={}
        for i in range(self.numberofhubs):
            dd[i]=Technologies
        self.Technologies=pd.Panel(dd)
    
    def TechOutput(self):
        TechOutputs=pd.read_excel(self.path,sheetname=self.TechSheet, skiprows=15, index_col=0, skip_footer=28) #Output matrix
        TechOutputs=TechOutputs.dropna(axis=0,how='all')  #Output matrix
        TechOutputs=TechOutputs.dropna(axis=1,how='all')  #Output matrix
        self.TechOutputs=TechOutputs
        
    def Demanddata(self):
        DemandDatas=pd.read_excel(self.path,sheetname=self.DemandSheet, header=None, skiprows=0)
        self.numberofdemands = DemandDatas[1][0]
        dd={}
        for i in range(self.numberofhubs):
            dd[i] = DemandDatas.loc[3:,(i+1)*self.numberofdemands-(self.numberofdemands-1):(i+1)*self.numberofdemands] #every i-th is new hub
        self.DemandData=pd.Panel(dd)
        
    def Storage(self):
        Storage=pd.read_excel(self.path,sheetname=self.TechSheet, skiprows=40, index_col=0, skip_footer=0, header = 0) #
        Storage=Storage.dropna(axis=1, how='all')
        Storage=Storage.fillna(0)
        self.StorageData=Storage
        
    def Hubs(self):
        number=pd.read_excel(self.path,sheetname=self.GeneralSheet, skiprows=17, index_col=0, skip_footer=0) #Output matrix
        number=number.dropna(axis=1,how='all')  #Output matrix
        number=number.iloc[0][0]
        self.numberofhubs=number
        
    
    
    
    #----------------------------------------------------------------------

    def Dict1D(self,dictVar,dataframe):
        for i,vali in enumerate(dataframe.index):
            dictVar[i+1]=round(dataframe.iloc[i][1],4)
        return dictVar

    def Dict1D_val_index(self,dictVar,dataframe):
        for i,vali in enumerate(dataframe.index):
            dictVar[vali]=round(dataframe.iloc[i][1],4)
        return dictVar

    def DictND(self,dictVar,dataframe):
        for i,vali in enumerate(dataframe.index):
            for j,valj in enumerate(dataframe.columns):
                #dictVar[vali,valj]=dataframe.iloc[i][j+1]
                dictVar[vali,valj]=dataframe.loc[vali][valj]
        return dictVar
    
    def DictPanel(self, dictVar,panel):
        for x,valx in enumerate(panel.items):
            for i, vali in enumerate(panel[valx].dropna(axis=0, how ='all').index):
                for j, valj in enumerate(panel[valx].dropna(axis=1, how ='all').columns):
                    #panel[valx] = panel[valx].dropna(axis=1)
                    #panel[valx] = panel[valx].dropna(axis=0,how='all')
                    dictVar[x+1,j+1, i+1] = panel[valx].loc[vali][valj]
        return dictVar
    
    
    #----------------------------------------------------------------------
    
    def Demands(self):
        dummy={}
        for i in range(self.DemandData.shape[0]):
            dummy[i]=self.DemandData[i].transpose()
        
        Demand=pd.Panel(dummy)
        loads_init={}
        loads_init=self.DictPanel(loads_init,Demand)
        return loads_init
    
    
    
    
    #----------------------------------------------------------------------
    
    def SolarData(self):
        SolarData=pd.read_excel(self.path,sheetname=self.SolarSheet)
        SolarData.columns=[1]
        solar_init={}
        solar_init=self.Dict1D(solar_init,SolarData)
        return solar_init
    
    
    
    
    #----------------------------------------------------------------------
    
    def CHP_list(self):
        Dispatch_tech=pd.DataFrame(self.TechOutputs.sum(0)) #find dispatch tech (CHP)
        CHP_setlist=[]
        for n,val in enumerate(Dispatch_tech[0]):
            if val>1:
                CHP_setlist.append(n+2) #first is electricity +1 since it starts at 0
        return CHP_setlist
    
    
    
    
    #----------------------------------------------------------------------
    
    def Roof_tech(self):
        Roof_techset=[]
        for n,val in enumerate(self.Technologies[0].loc["Area (m2)"]): #take only 0th item
            if val>0:
                Roof_techset.append(n+2) #first is electricity +1 since it starts at 0
                
        return Roof_techset
    
    
    
    
    #----------------------------------------------------------------------
        
    def cMatrix(self):
        
        #Based on the + - values, prepare data for generating coupling matrix        
        TechOutputs2=self.TechOutputs.multiply(np.array(self.Technologies[0].loc['Efficiency (%)']))
        TechOutputs2.loc[TechOutputs2.index!='Electricity']=TechOutputs2.loc[TechOutputs2.index!='Electricity'].multiply(np.array(self.Technologies[0].loc['Output ratio'].fillna(value=1).replace(0,1)))
        TechOutputs2[TechOutputs2<0]=-1

        addGrid=np.zeros(len(self.DemandData[0].dropna(axis=1, how ='all').columns),)
        addGrid[0]=1 #add electricity to coupling matrix
        Grid=pd.DataFrame(addGrid,columns=["Grid"],index=self.DemandData[0].dropna(axis=1, how ='all').columns).transpose()
        
        Cmatrix=TechOutputs2.transpose()
        Cmatrix.columns = list(range(1,len(Cmatrix.columns)+1))
        Cmatrix=pd.concat([Grid,Cmatrix])
        Cmatrix.index=list(range(1,len(TechOutputs2.columns)+2))
        Cmatrix.columns=list(range(1,len(TechOutputs2.index)+1))
        cMatrixDict={}
        cMatrixDict=self.DictND(cMatrixDict,Cmatrix)
        
        return cMatrixDict
    
    
    
    
    #----------------------------------------------------------------------
    
    def PartLoad(self):
        PartLoad=self.Technologies[0].loc["MinLoad (%)",]/100

        partload=self.TechOutputs.iloc[0:1].mul(list(PartLoad),axis=1)
        partload=pd.concat([partload,self.TechOutputs.iloc[1:].mul(list(PartLoad),axis=1)], axis=0)
        partload=partload.abs()
        partload=partload.transpose()
        partload.index=list(range(1+1,len(self.TechOutputs.columns)+2))
        partload.columns=list(range(1,len(self.TechOutputs.index)+1))
        SolartechsSets=list(compress(list(range(1+1,len(self.Technologies[0].columns)+2)), list(self.Technologies[0].loc["Area (m2)"]>0)))

        for i in SolartechsSets:
            partload.drop(i, inplace=True)

        PartloadInput={}
        PartloadInput=self.DictND(PartloadInput,partload)
        
        return PartloadInput
    
    
    
    
    #----------------------------------------------------------------------
    
    def MaxCapacityALL(self):
        maxCap={}
        for n in range(self.numberofhubs):
            MaxCap=pd.DataFrame(self.Technologies[n].loc["Maximum Capacity",])
            MaxCap.index=list(range(2,len(self.Technologies[n].loc["MinLoad (%)",].index)+2))
            maxCap[n]= MaxCap

            SolartechsSets=list(compress(list(range(1+1,len(self.Technologies[n].columns)+2)), list(self.Technologies[n].loc["Area (m2)"]>0)))
            #maxCap[n] = maxCap[n].drop(SolartechsSets)
            for x in SolartechsSets:
                maxCap[n].iloc[x-2] = list(data.Technologies[n].loc["Area (m2)"])[x-2]
            if self.numberofhubs>2:
                for k in maxCap[n].index:
                    if str(n+1) not in list(self.Technologies[n].loc["Hubs"][k-2]):
                        maxCap[n].loc[k] = 0
            elif self.numberofhubs==2:
                for k in maxCap[n].index:
                    if isinstance(data.Technologies[n].loc["Hubs"][k-2],float):
                        if int(n+1) != int(self.Technologies[n].loc["Hubs"][k-2]):
                            maxCap[n].loc[k] = 0
        
        CapacitiesPanel=pd.Panel(maxCap)
        
        Capacities = CapacitiesPanel.to_frame()
        Capacities.reset_index(inplace = True)
        Capacities.index = Capacities['major']
        del Capacities['major']
        del Capacities['minor']
        Capacities.columns = [int(x)+1 for x in Capacities.columns]
        del Capacities.index.name
        Capacities = Capacities.transpose()
        
        maximalcapacities={}
        maximalcapacities = self.DictND(maximalcapacities, Capacities)
        return maximalcapacities
    
    def MaxCapacity(self):
        maxCap={}
        for n in range(self.numberofhubs):
            MaxCap=pd.DataFrame(self.Technologies[n].loc["Maximum Capacity",])
            MaxCap.index=list(range(2,len(self.Technologies[n].loc["MinLoad (%)",].index)+2))
            maxCap[n]= MaxCap

            SolartechsSets=list(compress(list(range(1+1,len(self.Technologies[n].columns)+2)), list(self.Technologies[n].loc["Area (m2)"]>0)))
            maxCap[n] = maxCap[n].drop(SolartechsSets)
            if self.numberofhubs>2:
                for k in maxCap[n].index:
                    if str(n+1) not in list(self.Technologies[n].loc["Hubs"][k-2]):
                        maxCap[n].loc[k] = 0
            elif self.numberofhubs==2:
                for k in maxCap[n].index:
                    if isinstance(data.Technologies[n].loc["Hubs"][k-2],float):
                        if int(n+1) != int(self.Technologies[n].loc["Hubs"][k-2]):
                            maxCap[n].loc[k] = 0
                        
        CapacitiesPanel=pd.Panel(maxCap)
        
        Capacities = CapacitiesPanel.to_frame()
        Capacities.reset_index(inplace = True)
        Capacities.index = Capacities['major']
        del Capacities['major']
        del Capacities['minor']
        Capacities.columns = [int(x)+1 for x in Capacities.columns]
        del Capacities.index.name
        Capacities = Capacities.transpose()
        
        maximalcapacities={}
        maximalcapacities = self.DictND(maximalcapacities, Capacities)
        return maximalcapacities
     
    
    
    
    #----------------------------------------------------------------------
    
    def SolarSet(self):
        return list(compress(list(range(1+1,len(self.Technologies[0].columns)+2)), list(self.Technologies[0].loc["Area (m2)"]>0)))
    
    
    def DispTechsSet(self):
        return list(compress(list(range(1+1,len(self.Technologies[0].columns)+2)), list(self.Technologies[0].loc["Area (m2)"]==0)))

    
    def partloadtechs(self):
        PartLoad=self.Technologies[0].loc["MinLoad (%)",]/100

        partload=self.TechOutputs.iloc[0:1].mul(list(PartLoad),axis=1)
        partload=pd.concat([partload,self.TechOutputs.iloc[1:].mul(list(PartLoad),axis=1)], axis=0)
        partload=partload.abs()
        partload=partload.transpose()
        partload.index=list(range(1+1,len(self.TechOutputs.columns)+2))
        partload.columns=list(range(1,len(self.TechOutputs.index)+1))
        SolartechsSets=list(compress(list(range(1+1,len(self.Technologies[0].columns)+2)), list(self.Technologies[0].loc["Area (m2)"]>0)))

        for i in SolartechsSets:
            partload.drop(i, inplace=True)
            
        return list(partload.loc[partload.sum(axis=1)>0].index)
    
    
    #----------------------------------------------------------------------
    
    def LinearCost(self):
        dummy = {}
        for n in range(self.numberofhubs):
            LinearCost=self.Technologies[n].loc["CapCost (chf/kW)",]

            linCost=self.TechOutputs.iloc[0:1].mul(list(LinearCost),axis=1)
            linCost=pd.concat([linCost,self.TechOutputs.iloc[1:].mul(list(LinearCost),axis=1)], axis=0)

            linCost=linCost.transpose()
            for name in linCost.columns[1:]:
                linCost.loc[linCost["Electricity"] >1, name] = 0

            linCost.loc[linCost["Electricity"] <0, "Electricity"]=0
            linCost=linCost.abs()
            linCost.columns = self.DemandData[n].dropna(axis=1).columns

            addGrid=np.zeros(len(self.DemandData[0].dropna(axis=1).columns),)
            addGrid[0]=1 #add electricity to coupling matrix
            Grid=pd.DataFrame(addGrid,columns=["Grid"],index=self.DemandData[n].dropna(axis=1).columns).transpose()

            linCost=pd.concat([Grid,linCost])

            linCost.index=list(range(1,len(self.TechOutputs.columns)+2))
            linCost.columns=list(range(1,len(self.TechOutputs.index)+1))
            linCost.loc[1]=0
            
            dummy[n] = linCost.transpose()
        
        linCost = pd.Panel(dummy)
        linCapCosts={}
        linCapCosts=self.DictPanel(linCapCosts,linCost)
        
        return linCapCosts
     
    
    
    
    #----------------------------------------------------------------------
    ### Find which is the primary input for capacity #####
    def DisDemands(self):
        
        CHPlist=self.CHP_list()
        dispatch_demands=np.zeros((len(CHPlist), 2), dtype=int)

        for n,val in enumerate(CHPlist):
            counter=0
            for i, value in enumerate(np.array(self.TechOutputs[[val-2]],dtype=int)):
                if value[0]>0 and counter==0:
                    dispatch_demands[n,0]=i+1
                    counter=1
                if value[0]>0 and counter==1:
                    dispatch_demands[n,1]=i+1

        return dispatch_demands    
    
    
    
    #----------------------------------------------------------------------
    
    def InterestRate(self):
        Interest_rate=pd.read_excel(self.path,sheetname=self.GeneralSheet, skiprows=8, index_col=0, skip_footer=7) #
        Interest_rate=Interest_rate.dropna(axis=1,how='all')
        Interest_rate_R=Interest_rate.loc["Interest Rate r"][0]
        return Interest_rate_R
    
    
    
    
    #----------------------------------------------------------------------
    
    def LifeTime(self):
        dummy = {}
        for n in range(self.numberofhubs):
            Life=pd.DataFrame(list(self.Technologies[0].loc["Lifetime (yr)"]))
            Life.columns=[1]
            Life.index=list(range(2,len(self.TechOutputs.columns)+2))
            dummy[n]=Life
            
        Life = pd.Panel(dummy)
        
        Life= Life.to_frame()
        Life.reset_index(inplace = True)
        Life.index = Life['major']
        del Life['major']
        del Life['minor']
        Life.columns = [int(x)+1 for x in Life.columns]
        del Life.index.name
        Life = Life.transpose()

        lifeTimeTechs={}
        lifeTimeTechs=self.DictND(lifeTimeTechs, Life)
        return lifeTimeTechs
        
    
    
    
    #----------------------------------------------------------------------
        
    def NPV(self):
        Interest_rate_R=self.InterestRate()
        Life=pd.DataFrame(list(self.Technologies[0].loc["Lifetime (yr)"]))
        Life.columns=[1]
        Life.index=list(range(2,len(self.TechOutputs.columns)+2))
        
        NetPresentValue=1 / (((1 + Interest_rate_R) ** Life - 1) / (Interest_rate_R * ((1 + Interest_rate_R) ** Life)))
        NetPresentValueTech={}
        NetPresentValueTech=self.Dict1D_val_index(NetPresentValueTech,NetPresentValue)
        return NetPresentValueTech
        
    
    
    
    #----------------------------------------------------------------------
    
    def VarMaintCost(self):
        dummy = {}
        for n in range(self.numberofhubs):
            VarOMF=pd.DataFrame(list(self.Technologies[n].loc["OMVCost (chf/kWh)"]))
            VarOMF.columns=[1]
            VarOMF.index=list(range(1+1,len(self.TechOutputs.columns)+2))
            VarOMF.loc[1]=0
            dummy[n] = VarOMF
            
        VarOMF = pd.Panel(dummy)
        
        VarOMF= VarOMF.to_frame()
        VarOMF.reset_index(inplace = True)
        VarOMF.index = VarOMF['major']
        del VarOMF['major']
        del VarOMF['minor']
        VarOMF.columns = [int(x)+1 for x in VarOMF.columns]
        del VarOMF.index.name
        VarOMF = VarOMF.transpose()
        
        omvCosts={}
        omvCosts=self.DictND(omvCosts, VarOMF)
        return omvCosts
        
    
    
    
    #----------------------------------------------------------------------
    
    def CarbFactors(self):
        Carbon=pd.read_excel(self.path,sheetname=self.TechSheet, skiprows=24, index_col=0, skip_footer=16) #
        Carbon=Carbon.dropna(axis=0,how='all')
        Carbon=Carbon.dropna(axis=1,how='all')
        Carbon.index=[1]

        ElectricityCF=pd.read_excel(self.path,sheetname=self.GeneralSheet, skiprows=1, index_col=0, skip_footer=14) #
        ElectricityCF=ElectricityCF.dropna(axis=0,how='all')
        ElectricityCF=ElectricityCF.dropna(axis=1,how='all')
        del ElectricityCF["Price (chf/kWh)"]
        ElectricityCF.columns=[1]

        CarbonFactors= pd.concat([ElectricityCF.iloc[0], Carbon], axis=1)
        CarbonFactors.columns=list(range(1,len(CarbonFactors.columns)+1))
        CarbonFactors=CarbonFactors.transpose()

        carbonFactors={}
        carbonFactors=self.Dict1D(carbonFactors,CarbonFactors)
        
        return carbonFactors
       
    
    
    
    #----------------------------------------------------------------------
    
    def FuelPrice(self):
        Fuel=pd.read_excel(self.path,sheetname=self.GeneralSheet, skiprows=1, index_col=0, skip_footer=10) #
        Fuel=Fuel.dropna(axis=0,how='all')

        Carbon=pd.read_excel(self.path,sheetname=self.TechSheet, skiprows=24, index_col=0, skip_footer=16) #
        Carbon=Carbon.dropna(axis=0,how='all')
        Carbon=Carbon.dropna(axis=1,how='all')
        Carbon.index=[1]

        ElectricityCF=pd.read_excel(self.path,sheetname=self.GeneralSheet, skiprows=1, index_col=0, skip_footer=14) #
        ElectricityCF=ElectricityCF.dropna(axis=0,how='all')
        ElectricityCF=ElectricityCF.dropna(axis=1,how='all')
        del ElectricityCF["Price (chf/kWh)"]
        ElectricityCF.columns=[1]

        CarbonFactors= pd.concat([ElectricityCF.iloc[0], Carbon], axis=1)
        CarbonFactors.columns=list(range(1,len(CarbonFactors.columns)+1))
        CarbonFactors=CarbonFactors.transpose()

    
        for n,val in enumerate(Fuel["CO2 (kg/kWh)"]):
            for index,value in CarbonFactors.iterrows():
                if float(val)==float(value):
                    CarbonFactors.loc[index]=float(Fuel["Price (chf/kWh)"][n])

        opPrices={}
        opPrices=self.Dict1D(opPrices,CarbonFactors)
        
        return opPrices
     
    
    
    
    #----------------------------------------------------------------------
    
    def FeedIn(self):
        Tariff=pd.read_excel(self.path,sheetname=self.GeneralSheet, skiprows=11, index_col=0, skip_footer=1) #
        Tariff=Tariff.dropna(axis=0,how='all')
        Tariff=Tariff.dropna(axis=1,how='all')
        Tariff.columns=[1]
        Tariff.index=list(range(1,len(self.DemandData[0].dropna(axis=1).columns)+1))

        feedInTariffs={}
        feedInTariffs=self.Dict1D_val_index(feedInTariffs,Tariff)
        return feedInTariffs
    
    
    
    #### Storage ####
    #----------------------------------------------------------------------
    
    def StorageCh(self):
        maxStorCh={}
        MaxCharge=pd.DataFrame(list(self.StorageData.loc["max_charge"]))
        MaxCharge.columns=[1]
        MaxCharge = MaxCharge.transpose()
        MaxCharge.columns = [int(x)+1 for x in MaxCharge.columns]
        for i in range(2,self.numberofhubs+1):
            MaxCharge.loc[i] = MaxCharge.iloc[0]
        maxStorCh=self.DictND(maxStorCh, MaxCharge)
        
        return maxStorCh
    
    
    def StorageDisch(self):
        maxStorDisch={}
        MaxDischarge=pd.DataFrame(list(self.StorageData.loc["max_discharge"]))
        MaxDischarge.columns=[1]
        MaxDischarge = MaxDischarge.transpose()
        MaxDischarge.columns = [int(x)+1 for x in MaxDischarge.columns]
        for i in range(2,self.numberofhubs+1):
            MaxDischarge.loc[i] = MaxDischarge.iloc[0]
        maxStorDisch=self.DictND(maxStorDisch, MaxDischarge)
        return maxStorDisch
    
    
    def StorageLoss(self):
        lossesStorStanding={}
        losses=pd.DataFrame(list(self.StorageData.loc["decay"]))
        losses.columns=[1]
        losses = losses.transpose()
        losses.columns = [int(x)+1 for x in losses.columns]
        for i in range(2,self.numberofhubs+1):
            losses.loc[i] = losses.iloc[0]
        lossesStorStanding=self.DictND(lossesStorStanding, losses)
        return lossesStorStanding
    
    
    def StorageEfCh(self):
        chargingEff={}
        Ch_eff=pd.DataFrame(list(self.StorageData.loc["ch_eff"]))
        Ch_eff.columns=[1]
        Ch_eff = Ch_eff.transpose()
        Ch_eff.columns = [int(x)+1 for x in Ch_eff.columns]
        for i in range(2,self.numberofhubs+1):
            Ch_eff.loc[i] = Ch_eff.iloc[0]
        chargingEff=self.DictND(chargingEff, Ch_eff)
        return chargingEff
    
    def StorageEfDisch(self):
        dischLosses={}
        Disch_eff=pd.DataFrame(list(self.StorageData.loc["disch_eff"]))
        Disch_eff.columns=[1]
        Disch_eff = Disch_eff.transpose()
        Disch_eff.columns = [int(x)+1 for x in Disch_eff.columns]
        for i in range(2,self.numberofhubs+1):
            Disch_eff.loc[i] = Disch_eff.iloc[0]
        dischLosses=self.DictND(dischLosses, Disch_eff)
        return dischLosses
    
    
    def StorageMinSoC(self):
        minSoC={}
        min_state=pd.DataFrame(list(self.StorageData.loc["min_state"]))
        min_state.columns=[1]
        min_state = min_state.transpose()
        min_state.columns = [int(x)+1 for x in min_state.columns]
        for i in range(2,self.numberofhubs+1):
            min_state.loc[i] = min_state.iloc[0]
        minSoC=self.DictND(minSoC, min_state)
        return minSoC
    
    
    def StorageLife(self):
        lifeTimeStorages={}
        LifeBattery=pd.DataFrame(list(self.StorageData.loc["LifeBat (year)"]))
        LifeBattery.columns=[1]
        LifeBattery = LifeBattery.transpose()
        LifeBattery.columns = [int(x)+1 for x in LifeBattery.columns]
        for i in range(2,self.numberofhubs+1):
            LifeBattery.loc[i] = LifeBattery.iloc[0]
        lifeTimeStorages=self.DictND(lifeTimeStorages, LifeBattery)
        return lifeTimeStorages
    
    
    def StorageLinCost(self):
        linStorageCosts={}
        LinearCostStorage=pd.DataFrame(list(self.StorageData.loc["CostBat (chf/kWh)"]))
        LinearCostStorage.columns=[1]
        LinearCostStorage = LinearCostStorage.transpose()
        LinearCostStorage.columns = [int(x)+1 for x in LinearCostStorage.columns]
        for i in range(2,self.numberofhubs+1):
            LinearCostStorage.loc[i] = LinearCostStorage.iloc[0]
        linStorageCosts=self.DictND(linStorageCosts, LinearCostStorage)
        return linStorageCosts
    
    
    def StorageNPV(self):
        Interest_rate_R=self.InterestRate()
        LifeBattery=pd.DataFrame(list(self.StorageData.loc["LifeBat (year)"]))
        LifeBattery.columns=[1]
        NetPresentValueStor={}
        NetPresentValueStorage=1 / (((1 + Interest_rate_R) ** LifeBattery - 1) / (Interest_rate_R * ((1 + Interest_rate_R) ** LifeBattery)))
        '''
        NetPresentValueStorage.columns = [1]
        NetPresentValueStorage = NetPresentValueStorage.transpose()
        NetPresentValueStorage.columns = [int(x)+1 for x in NetPresentValueStorage.columns]
        for i in range(2,self.numberofhubs+1):
            NetPresentValueStorage.loc[i] = NetPresentValueStorage.iloc[0]
        NetPresentValueStor=self.DictND(NetPresentValueStor,NetPresentValueStorage)
        return NetPresentValueStor
        '''
        NetPresentValueStor=self.Dict1D(NetPresentValueStor,NetPresentValueStorage)
        return NetPresentValueStor
    
    def StorageBinary(self):
        dummy = np.zeros((self.numberofhubs, self.numberofdemands, ))
        for i in range(self.numberofdemands):
            for j in range(self.numberofhubs):
                if str(j+1) in list(self.StorageData.loc["Hubs"][i]):
                    dummy[j,i] = 1

        StorageY= pd.DataFrame(dummy)
        StorageY.columns= [int(x)+1 for x in StorageY.columns]
        StorageY.index = [int(x)+1 for x in StorageY.index]

        StorageYbinary={}
        StorageYbinary = self.DictND(StorageYbinary, StorageY)
        return StorageYbinary

# %%
excel_path=r'C:\Users\mobo\OneDrive\0PhD\Python-based energy hub\Generic_energy_hub_PYTHON\data\General_input_MultiV2.xlsx'
data=InputData(excel_path)

# %%
#-----------------------------------------------------------------------------#
## Creating a model ##
#-----------------------------------------------------------------------------#

model = ConcreteModel()

# sets definition
model.Time = RangeSet(1, data.DemandData.shape[1]) #0 is items, 1 is row
model.SubTime = RangeSet(2, data.DemandData.shape[1], within=model.Time) #0 is items, 1 is row
model.In = RangeSet(1, data.Technologies.shape[2]+1) #0 is items, 1 is row , 2 is column , it is assumed that the layout of hub's technologies is the same and the choice of technology is controled by max cap in each DF
#model.W_Ogrid = Set(initialize=list(range(1+1,len(data.Technologies.columns)+2)), within=model.In) #techs w/o grid


model.Out = RangeSet(1, data.numberofdemands) #0 is items, 1 is row , 2 is column
number_of_demands= list(range(1, data.numberofdemands+1))

model.SolarTechs = Set(initialize=data.SolarSet(), within=model.In)

model.DispTechs = Set(initialize=data.DispTechsSet(), within=model.In)
model.Techs = Set(initialize=list(range(2,data.Technologies[0].shape[1]+2)), within=model.In)
model.PartLoad=Set(initialize=data.partloadtechs(), within=model.In)

model.CHP = Set(initialize=data.CHP_list(), within=model.In) # set dispatch tech set
model.roof_tech = Set(initialize=data.Roof_tech(), within=model.In) # set tech with roof area set
#model.gas_tech = Set(initialize=[3,4,7,8], within=model.In) #

numberofhubs=data.DemandData.shape[0]
model.hubs=RangeSet(1,data.DemandData.shape[0]) #0 is items /number of hubs
model.hub_i=RangeSet(1,data.DemandData.shape[0], within=model.hubs)
#model.hub_j=Set(within=model.hubs)
model.hub_j=RangeSet(1,data.DemandData.shape[0], within=model.hubs)


# coupling matrix & Technical parameters
model.cMatrix = Param(model.In, model.Out, initialize=data.cMatrix())                                      # coupling matrix technology efficiencies 
model.maxCapTechs = Param(model.hubs, model.DispTechs, initialize=data.MaxCapacity())
model.maxCapTechsAll = Param(model.hubs, model.Techs, initialize=data.MaxCapacityALL())
model.maxStorCh = Param(model.hubs, model.Out, initialize=data.StorageCh())
model.maxStorDisch = Param(model.hubs, model.Out, initialize= data.StorageDisch())

model.lossesStorStanding = Param(model.hubs, model.Out, initialize = data.StorageLoss())
model.chargingEff = Param(model.hubs, model.Out, initialize = data.StorageEfCh())
model.dischLosses = Param(model.hubs, model.Out, initialize = data.StorageEfDisch())
model.minSoC = Param(model.hubs, model.Out, initialize = data.StorageMinSoC())
model.partLoad = Param(model.In, model.Out, initialize=data.PartLoad()) #PartloadInput
model.maxSolarArea = Param(initialize=500)

# carbon factors
model.carbonFactors = Param(model.In, initialize=data.CarbFactors())
model.maxCarbon = Param(initialize=650000)

# Cost parameters
model.linCapCosts = Param(model.hubs, model.In, model.Out, initialize= data.LinearCost())         # Technologies capital costs
model.linStorageCosts = Param(model.hubs, model.Out, initialize = data.StorageLinCost())
model.opPrices = Param( model.In, initialize=data.FuelPrice())   #model.hubs,                    # Operating prices technologies
model.feedInTariffs = Param(model.Out, initialize=data.FeedIn())               # feed-in tariffs
model.omvCosts = Param(model.hubs, model.In, initialize=data.VarMaintCost())                            # Maintenance costs
model.interestRate = Param(within=NonNegativeReals, initialize=data.InterestRate())
# lifetime
model.lifeTimeTechs = Param(model.hubs, model.In, initialize = data.LifeTime())
model.lifeTimeStorages = Param(model.hubs, model.Out, initialize = data.StorageLife())

## DH parameters
model.HeatLosses=Param(model.hub_i, model.hub_j, initialize=0.001)
#model.Distance=Param(model.hub_i, model.hub_j, initialize=)
model.PipeCost=Param(initialize=200)
model.Losses=Param(model.hub_i, model.hub_j, initialize=0.001 )


## Declaring Global Parameters ##
model.timeHorizon = Param(within=NonNegativeReals, initialize=20)
model.bigM = Param(within=NonNegativeReals, initialize=5000)

#loads

model.loads = Param(model.hub_i, model.Time, model.Out, initialize=data.Demands())
model.solarEm = Param( model.Time, initialize=data.SolarData())


## Global variables
model.P = Var(model.hubs, model.Time, model.In, domain=NonNegativeReals)
model.Pexport = Var(model.hubs, model.Time, model.Out, domain=NonNegativeReals)
model.Capacities = Var(model.hubs, model.In, model.Out, domain=NonNegativeReals)
model.Ytechnologies = Var(model.hubs, model.In, model.Out, domain=Binary)
model.Yon = Var(model.hubs, model.Time, model.In, domain=Binary)
model.TotalCost = Var(domain=Reals)
model.OpCost = Var(domain=NonNegativeReals)
model.MaintCost = Var(domain=NonNegativeReals)
model.IncomeExp = Var(domain=NonNegativeReals)
model.InvCost = Var(domain=NonNegativeReals)
model.TotalCarbon = Var(domain=Reals)
model.TotalCarbon2 = Var(domain=Reals)
model.NetPresentValueTech = Param(model.In, domain=NonNegativeReals, initialize=data.NPV())
model.NetPresentValueStor = Param(model.Out, domain=NonNegativeReals, initialize=data.StorageNPV())

## DH variables
model.DH_Q = Var(model.hub_i, model.hub_j,model.Time, model.Out, domain=NonNegativeReals)
model.Ypipeline = Var(model.hub_i, model.hub_j, domain=Binary)

                      
#Storage variables
model.Qin = Var(model.hubs, model.Time, model.Out, domain=NonNegativeReals)
model.Qout = Var(model.hubs, model.Time, model.Out, domain=NonNegativeReals)
model.E = Var(model.hubs, model.Time, model.Out, domain=NonNegativeReals)
model.StorageCap = Var(model.hubs, model.Out, domain=NonNegativeReals)
#model.Ystorage = Var(model.hubs, model.Out, domain=Binary)
model.Ystorage = Param(model.hubs, model.Out, domain=Binary, initialize=data.StorageBinary())
#model.maxStorageCap = Param(model.Out, initialize= maxStorageCap)

# %%
model.capacityConst.display()
# Out:
# capacityConst : Size=2700
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,16,8]
# 	    (expression: 0.519*P[5,16,8] - Capacities[5,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,13,4]
# 	    (expression: 0.3*P[4,13,4] - Capacities[4,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,29,8]
# 	    (expression: 0.519*P[2,29,8] - Capacities[2,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,20,7]
# 	    (expression: 0.3*P[3,20,7] - Capacities[3,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,19,4]
# 	    (expression: 0.519*P[5,19,4] - Capacities[5,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,38,5]
# 	    (expression: 0.14*P[1,38,5] - Capacities[1,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,25,8]
# 	    (expression: 0.3*P[4,25,8] - Capacities[4,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,36,4]
# 	    (expression: 0.3*P[2,36,4] - Capacities[2,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,29,1]
# 	    (expression: P[5,29,1] - Capacities[5,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,18,8]
# 	    (expression: 0.3*P[1,18,8] - Capacities[1,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,3,4]
# 	    (expression: 0.3*P[4,3,4] - Capacities[4,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,24,1]
# 	    (expression: P[2,24,1] - Capacities[2,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,4,4]
# 	    (expression: 0.519*P[1,4,4] - Capacities[1,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,31,7]
# 	    (expression: 0.3*P[3,31,7] - Capacities[3,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,1,4]
# 	    (expression: 0.3*P[5,1,4] - Capacities[5,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,38,1]
# 	    (expression: P[3,38,1] - Capacities[3,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,11,8]
# 	    (expression: 0.519*P[4,11,8] - Capacities[4,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,33,9]
# 	    (expression: 0.94*P[5,33,9] - Capacities[5,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,36,6]
# 	    (expression: 0.46*P[1,36,6] - Capacities[1,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,12,9]
# 	    (expression: 0.94*P[4,12,9] - Capacities[4,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,45,7]
# 	    (expression: 0.3*P[2,45,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,12,9]
# 	    (expression: 0.94*P[2,12,9] - Capacities[2,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,42,7]
# 	    (expression: 0.3*P[5,42,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,39,6]
# 	    (expression: 0.46*P[2,39,6] - Capacities[2,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,8,4]
# 	    (expression: 0.519*P[2,8,4] - Capacities[2,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,3,1]
# 	    (expression: P[4,3,1] - Capacities[4,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,32,8]
# 	    (expression: 0.3*P[4,32,8] - Capacities[4,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,3,8]
# 	    (expression: 0.3*P[5,3,8] - Capacities[5,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,38,5]
# 	    (expression: 0.14*P[4,38,5] - Capacities[4,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,20,8]
# 	    (expression: 0.519*P[3,20,8] - Capacities[3,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,40,6]
# 	    (expression: 0.46*P[2,40,6] - Capacities[2,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,11,2]
# 	    (expression: 3.2*P[2,11,2] - Capacities[2,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,16,1]
# 	    (expression: P[4,16,1] - Capacities[4,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,34,7]
# 	    (expression: 0.3*P[2,34,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,2,6]
# 	    (expression: 0.46*P[5,2,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,27,1]
# 	    (expression: P[1,27,1] - Capacities[1,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,31,3]
# 	    (expression: 0.94*P[3,31,3] - Capacities[3,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,23,9]
# 	    (expression: 0.94*P[4,23,9] - Capacities[4,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,26,9]
# 	    (expression: 0.94*P[4,26,9] - Capacities[4,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,34,4]
# 	    (expression: 0.519*P[5,34,4] - Capacities[5,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,44,3]
# 	    (expression: 0.94*P[1,44,3] - Capacities[1,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,36,5]
# 	    (expression: 0.14*P[5,36,5] - Capacities[5,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,17,9]
# 	    (expression: 0.94*P[1,17,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,28,3]
# 	    (expression: 0.94*P[2,28,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,23,4]
# 	    (expression: 0.3*P[1,23,4] - Capacities[1,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,8,7]
# 	    (expression: 0.3*P[5,8,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,23,7]
# 	    (expression: 0.3*P[2,23,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,12,4]
# 	    (expression: 0.519*P[4,12,4] - Capacities[4,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,43,4]
# 	    (expression: 0.3*P[2,43,4] - Capacities[2,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,19,8]
# 	    (expression: 0.519*P[2,19,8] - Capacities[2,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,6,7]
# 	    (expression: 0.3*P[1,6,7] - Capacities[1,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,9,3]
# 	    (expression: 0.94*P[1,9,3] - Capacities[1,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,21,8]
# 	    (expression: 0.519*P[1,21,8] - Capacities[1,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,36,1]
# 	    (expression: P[5,36,1] - Capacities[5,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,10,9]
# 	    (expression: 0.94*P[3,10,9] - Capacities[3,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,23,3]
# 	    (expression: 0.94*P[2,23,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,45,8]
# 	    (expression: 0.3*P[2,45,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,44,9]
# 	    (expression: 0.94*P[5,44,9] - Capacities[5,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,34,7]
# 	    (expression: 0.3*P[4,34,7] - Capacities[4,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,45,4]
# 	    (expression: 0.519*P[4,45,4] - Capacities[4,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,3,6]
# 	    (expression: 0.46*P[5,3,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,2,2]
# 	    (expression: 3.2*P[3,2,2] - Capacities[3,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,33,6]
# 	    (expression: 0.46*P[4,33,6] - Capacities[4,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,17,4]
# 	    (expression: 0.519*P[1,17,4] - Capacities[1,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,15,9]
# 	    (expression: 0.94*P[2,15,9] - Capacities[2,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,2,9]
# 	    (expression: 0.94*P[2,2,9] - Capacities[2,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,8,7]
# 	    (expression: 0.519*P[4,8,7] - Capacities[4,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,40,1]
# 	    (expression: P[5,40,1] - Capacities[5,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,27,4]
# 	    (expression: 0.519*P[5,27,4] - Capacities[5,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,5,1]
# 	    (expression: P[2,5,1] - Capacities[2,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,11,7]
# 	    (expression: 0.3*P[1,11,7] - Capacities[1,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,22,7]
# 	    (expression: 0.519*P[1,22,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,8,5]
# 	    (expression: 0.14*P[1,8,5] - Capacities[1,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,29,2]
# 	    (expression: 3.2*P[1,29,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,29,4]
# 	    (expression: 0.519*P[4,29,4] - Capacities[4,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,19,8]
# 	    (expression: 0.519*P[5,19,8] - Capacities[5,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,5,9]
# 	    (expression: 0.94*P[4,5,9] - Capacities[4,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,25,9]
# 	    (expression: 0.94*P[4,25,9] - Capacities[4,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,26,4]
# 	    (expression: 0.519*P[4,26,4] - Capacities[4,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,26,5]
# 	    (expression: 0.14*P[2,26,5] - Capacities[2,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,18,9]
# 	    (expression: 0.94*P[1,18,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,10,4]
# 	    (expression: 0.3*P[2,10,4] - Capacities[2,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,16,7]
# 	    (expression: 0.3*P[3,16,7] - Capacities[3,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,15,7]
# 	    (expression: 0.519*P[3,15,7] - Capacities[3,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,34,5]
# 	    (expression: 0.14*P[1,34,5] - Capacities[1,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,45,1]
# 	    (expression: P[4,45,1] - Capacities[4,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,7,6]
# 	    (expression: 0.46*P[1,7,6] - Capacities[1,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,36,3]
# 	    (expression: 0.94*P[2,36,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,14,1]
# 	    (expression: P[1,14,1] - Capacities[1,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,24,3]
# 	    (expression: 0.94*P[5,24,3] - Capacities[5,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,12,8]
# 	    (expression: 0.3*P[2,12,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,39,4]
# 	    (expression: 0.519*P[1,39,4] - Capacities[1,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,1,5]
# 	    (expression: 0.14*P[4,1,5] - Capacities[4,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,16,3]
# 	    (expression: 0.94*P[3,16,3] - Capacities[3,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,5,4]
# 	    (expression: 0.3*P[5,5,4] - Capacities[5,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,32,7]
# 	    (expression: 0.519*P[3,32,7] - Capacities[3,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,4,9]
# 	    (expression: 0.94*P[1,4,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,40,8]
# 	    (expression: 0.519*P[2,40,8] - Capacities[2,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,32,6]
# 	    (expression: 0.46*P[1,32,6] - Capacities[1,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,3,8]
# 	    (expression: 0.519*P[1,3,8] - Capacities[1,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,38,4]
# 	    (expression: 0.519*P[4,38,4] - Capacities[4,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,5,5]
# 	    (expression: 0.14*P[1,5,5] - Capacities[1,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,42,8]
# 	    (expression: 0.519*P[3,42,8] - Capacities[3,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,12,4]
# 	    (expression: 0.519*P[2,12,4] - Capacities[2,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,12,2]
# 	    (expression: 3.2*P[1,12,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,8,2]
# 	    (expression: 3.2*P[5,8,2] - Capacities[5,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,13,3]
# 	    (expression: 0.94*P[3,13,3] - Capacities[3,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,43,2]
# 	    (expression: 3.2*P[1,43,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,3,6]
# 	    (expression: 0.46*P[4,3,6] - Capacities[4,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,44,6]
# 	    (expression: 0.46*P[2,44,6] - Capacities[2,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,28,7]
# 	    (expression: 0.3*P[5,28,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,31,4]
# 	    (expression: 0.3*P[4,31,4] - Capacities[4,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,17,8]
# 	    (expression: 0.3*P[1,17,8] - Capacities[1,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,38,7]
# 	    (expression: 0.3*P[2,38,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,11,7]
# 	    (expression: 0.519*P[2,11,7] - Capacities[2,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,14,4]
# 	    (expression: 0.3*P[3,14,4] - Capacities[3,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,42,2]
# 	    (expression: 3.2*P[1,42,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,31,7]
# 	    (expression: 0.519*P[3,31,7] - Capacities[3,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,30,5]
# 	    (expression: 0.14*P[3,30,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,25,6]
# 	    (expression: 0.46*P[5,25,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,3,7]
# 	    (expression: 0.3*P[5,3,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,19,4]
# 	    (expression: 0.3*P[1,19,4] - Capacities[1,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,45,5]
# 	    (expression: 0.14*P[3,45,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,29,7]
# 	    (expression: 0.519*P[5,29,7] - Capacities[5,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,37,8]
# 	    (expression: 0.519*P[4,37,8] - Capacities[4,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,18,7]
# 	    (expression: 0.519*P[4,18,7] - Capacities[4,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,45,8]
# 	    (expression: 0.3*P[5,45,8] - Capacities[5,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,29,7]
# 	    (expression: 0.519*P[1,29,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,16,3]
# 	    (expression: 0.94*P[1,16,3] - Capacities[1,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,25,8]
# 	    (expression: 0.3*P[3,25,8] - Capacities[3,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,23,7]
# 	    (expression: 0.519*P[5,23,7] - Capacities[5,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,35,1]
# 	    (expression: P[2,35,1] - Capacities[2,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,26,4]
# 	    (expression: 0.3*P[5,26,4] - Capacities[5,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,27,9]
# 	    (expression: 0.94*P[2,27,9] - Capacities[2,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,42,5]
# 	    (expression: 0.14*P[5,42,5] - Capacities[5,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,38,7]
# 	    (expression: 0.3*P[4,38,7] - Capacities[4,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,39,7]
# 	    (expression: 0.519*P[1,39,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,45,4]
# 	    (expression: 0.519*P[5,45,4] - Capacities[5,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,13,9]
# 	    (expression: 0.94*P[1,13,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,8,4]
# 	    (expression: 0.519*P[5,8,4] - Capacities[5,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,33,2]
# 	    (expression: 3.2*P[2,33,2] - Capacities[2,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,25,8]
# 	    (expression: 0.3*P[2,25,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,36,8]
# 	    (expression: 0.519*P[1,36,8] - Capacities[1,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,16,8]
# 	    (expression: 0.519*P[4,16,8] - Capacities[4,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,35,9]
# 	    (expression: 0.94*P[1,35,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,18,7]
# 	    (expression: 0.519*P[1,18,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,4,6]
# 	    (expression: 0.46*P[2,4,6] - Capacities[2,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,44,1]
# 	    (expression: P[1,44,1] - Capacities[1,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,19,4]
# 	    (expression: 0.3*P[4,19,4] - Capacities[4,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,42,8]
# 	    (expression: 0.3*P[2,42,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,35,5]
# 	    (expression: 0.14*P[4,35,5] - Capacities[4,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,30,5]
# 	    (expression: 0.14*P[2,30,5] - Capacities[2,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,14,4]
# 	    (expression: 0.3*P[2,14,4] - Capacities[2,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,11,7]
# 	    (expression: 0.519*P[3,11,7] - Capacities[3,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,17,8]
# 	    (expression: 0.3*P[4,17,8] - Capacities[4,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,32,3]
# 	    (expression: 0.94*P[5,32,3] - Capacities[5,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,26,8]
# 	    (expression: 0.3*P[1,26,8] - Capacities[1,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,13,3]
# 	    (expression: 0.94*P[2,13,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,12,2]
# 	    (expression: 3.2*P[4,12,2] - Capacities[4,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,12,4]
# 	    (expression: 0.519*P[3,12,4] - Capacities[3,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,35,4]
# 	    (expression: 0.519*P[1,35,4] - Capacities[1,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,5,5]
# 	    (expression: 0.14*P[4,5,5] - Capacities[4,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,3,8]
# 	    (expression: 0.519*P[4,3,8] - Capacities[4,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,43,7]
# 	    (expression: 0.3*P[3,43,7] - Capacities[3,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,40,2]
# 	    (expression: 3.2*P[3,40,2] - Capacities[3,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,4,9]
# 	    (expression: 0.94*P[4,4,9] - Capacities[4,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,37,7]
# 	    (expression: 0.519*P[5,37,7] - Capacities[5,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,16,3]
# 	    (expression: 0.94*P[2,16,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,1,5]
# 	    (expression: 0.14*P[1,1,5] - Capacities[1,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,12,8]
# 	    (expression: 0.3*P[3,12,8] - Capacities[3,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,14,1]
# 	    (expression: P[4,14,1] - Capacities[4,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,12,7]
# 	    (expression: 0.519*P[1,12,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,15,7]
# 	    (expression: 0.519*P[2,15,7] - Capacities[2,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,16,7]
# 	    (expression: 0.3*P[2,16,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,10,4]
# 	    (expression: 0.3*P[3,10,4] - Capacities[3,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,18,9]
# 	    (expression: 0.94*P[4,18,9] - Capacities[4,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,26,5]
# 	    (expression: 0.14*P[3,26,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,29,6]
# 	    (expression: 0.46*P[5,29,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,25,9]
# 	    (expression: 0.94*P[1,25,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,7,7]
# 	    (expression: 0.3*P[5,7,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,29,4]
# 	    (expression: 0.519*P[1,29,4] - Capacities[1,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,28,8]
# 	    (expression: 0.3*P[5,28,8] - Capacities[5,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,29,2]
# 	    (expression: 3.2*P[4,29,2] - Capacities[4,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,27,8]
# 	    (expression: 0.519*P[2,27,8] - Capacities[2,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,22,7]
# 	    (expression: 0.519*P[4,22,7] - Capacities[4,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,30,2]
# 	    (expression: 3.2*P[1,30,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,5,1]
# 	    (expression: P[3,5,1] - Capacities[3,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,34,8]
# 	    (expression: 0.3*P[4,34,8] - Capacities[4,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,42,4]
# 	    (expression: 0.519*P[1,42,4] - Capacities[1,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,39,5]
# 	    (expression: 0.14*P[3,39,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,2,9]
# 	    (expression: 0.94*P[3,2,9] - Capacities[3,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,15,9]
# 	    (expression: 0.94*P[3,15,9] - Capacities[3,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,17,4]
# 	    (expression: 0.519*P[4,17,4] - Capacities[4,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,2,2]
# 	    (expression: 3.2*P[2,2,2] - Capacities[2,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,27,9]
# 	    (expression: 0.94*P[5,27,9] - Capacities[5,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,30,4]
# 	    (expression: 0.3*P[5,30,4] - Capacities[5,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,27,7]
# 	    (expression: 0.3*P[4,27,7] - Capacities[4,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,35,7]
# 	    (expression: 0.519*P[1,35,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,40,7]
# 	    (expression: 0.519*P[4,40,7] - Capacities[4,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,2,1]
# 	    (expression: P[5,2,1] - Capacities[5,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,23,3]
# 	    (expression: 0.94*P[3,23,3] - Capacities[3,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,10,9]
# 	    (expression: 0.94*P[2,10,9] - Capacities[2,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,12,4]
# 	    (expression: 0.519*P[5,12,4] - Capacities[5,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,25,7]
# 	    (expression: 0.3*P[5,25,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,44,4]
# 	    (expression: 0.3*P[2,44,4] - Capacities[2,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,21,1]
# 	    (expression: P[5,21,1] - Capacities[5,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,8,9]
# 	    (expression: 0.94*P[5,8,9] - Capacities[5,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,9,3]
# 	    (expression: 0.94*P[4,9,3] - Capacities[4,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,33,7]
# 	    (expression: 0.519*P[2,33,7] - Capacities[2,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,15,8]
# 	    (expression: 0.519*P[5,15,8] - Capacities[5,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,19,8]
# 	    (expression: 0.519*P[3,19,8] - Capacities[3,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,29,8]
# 	    (expression: 0.519*P[4,29,8] - Capacities[4,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,12,4]
# 	    (expression: 0.519*P[1,12,4] - Capacities[1,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,23,7]
# 	    (expression: 0.3*P[3,23,7] - Capacities[3,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,25,4]
# 	    (expression: 0.3*P[5,25,4] - Capacities[5,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,23,4]
# 	    (expression: 0.3*P[4,23,4] - Capacities[4,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,44,2]
# 	    (expression: 3.2*P[4,44,2] - Capacities[4,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,44,6]
# 	    (expression: 0.46*P[1,44,6] - Capacities[1,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,28,3]
# 	    (expression: 0.94*P[4,28,3] - Capacities[4,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,26,9]
# 	    (expression: 0.94*P[1,26,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,23,9]
# 	    (expression: 0.94*P[1,23,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,45,2]
# 	    (expression: 3.2*P[3,45,2] - Capacities[3,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,27,1]
# 	    (expression: P[4,27,1] - Capacities[4,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,29,2]
# 	    (expression: 3.2*P[5,29,2] - Capacities[5,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,38,2]
# 	    (expression: 3.2*P[5,38,2] - Capacities[5,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,39,8]
# 	    (expression: 0.519*P[3,39,8] - Capacities[3,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,16,1]
# 	    (expression: P[1,16,1] - Capacities[1,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,11,2]
# 	    (expression: 3.2*P[3,11,2] - Capacities[3,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,16,7]
# 	    (expression: 0.3*P[5,16,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,7,4]
# 	    (expression: 0.3*P[2,7,4] - Capacities[2,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,42,7]
# 	    (expression: 0.3*P[2,42,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,26,6]
# 	    (expression: 0.46*P[5,26,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,3,1]
# 	    (expression: P[1,3,1] - Capacities[1,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,8,4]
# 	    (expression: 0.519*P[3,8,4] - Capacities[3,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,5,7]
# 	    (expression: 0.3*P[4,5,7] - Capacities[4,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,12,9]
# 	    (expression: 0.94*P[3,12,9] - Capacities[3,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,32,8]
# 	    (expression: 0.519*P[4,32,8] - Capacities[4,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,12,9]
# 	    (expression: 0.94*P[1,12,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,37,2]
# 	    (expression: 3.2*P[3,37,2] - Capacities[3,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,11,8]
# 	    (expression: 0.519*P[1,11,8] - Capacities[1,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,31,4]
# 	    (expression: 0.3*P[1,31,4] - Capacities[1,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,31,7]
# 	    (expression: 0.3*P[2,31,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,4,4]
# 	    (expression: 0.519*P[4,4,4] - Capacities[4,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,34,8]
# 	    (expression: 0.519*P[3,34,8] - Capacities[3,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,12,5]
# 	    (expression: 0.14*P[5,12,5] - Capacities[5,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,24,1]
# 	    (expression: P[3,24,1] - Capacities[3,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,8,7]
# 	    (expression: 0.519*P[1,8,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,18,3]
# 	    (expression: 0.94*P[5,18,3] - Capacities[5,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,25,8]
# 	    (expression: 0.3*P[1,25,8] - Capacities[1,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,39,1]
# 	    (expression: P[3,39,1] - Capacities[3,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,31,3]
# 	    (expression: 0.94*P[2,31,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,29,8]
# 	    (expression: 0.519*P[3,29,8] - Capacities[3,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,33,4]
# 	    (expression: 0.519*P[2,33,4] - Capacities[2,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,40,5]
# 	    (expression: 0.14*P[4,40,5] - Capacities[4,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,37,3]
# 	    (expression: 0.94*P[5,37,3] - Capacities[5,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,40,8]
# 	    (expression: 0.519*P[5,40,8] - Capacities[5,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,26,2]
# 	    (expression: 3.2*P[3,26,2] - Capacities[3,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,6,2]
# 	    (expression: 3.2*P[4,6,2] - Capacities[4,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,5,8]
# 	    (expression: 0.519*P[2,5,8] - Capacities[2,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,25,4]
# 	    (expression: 0.519*P[1,25,4] - Capacities[1,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,34,3]
# 	    (expression: 0.94*P[4,34,3] - Capacities[4,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,5,9]
# 	    (expression: 0.94*P[5,5,9] - Capacities[5,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,15,8]
# 	    (expression: 0.3*P[3,15,8] - Capacities[3,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,25,1]
# 	    (expression: P[4,25,1] - Capacities[4,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,15,7]
# 	    (expression: 0.3*P[4,15,7] - Capacities[4,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,37,9]
# 	    (expression: 0.94*P[3,37,9] - Capacities[3,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,13,1]
# 	    (expression: P[2,13,1] - Capacities[2,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,43,3]
# 	    (expression: 0.94*P[3,43,3] - Capacities[3,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,30,7]
# 	    (expression: 0.519*P[1,30,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,16,2]
# 	    (expression: 3.2*P[2,16,2] - Capacities[2,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,39,7]
# 	    (expression: 0.519*P[5,39,7] - Capacities[5,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,5,2]
# 	    (expression: 3.2*P[1,5,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,36,9]
# 	    (expression: 0.94*P[3,36,9] - Capacities[3,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,30,4]
# 	    (expression: 0.3*P[3,30,4] - Capacities[3,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,17,5]
# 	    (expression: 0.14*P[2,17,5] - Capacities[2,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,10,6]
# 	    (expression: 0.46*P[4,10,6] - Capacities[4,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,31,5]
# 	    (expression: 0.14*P[5,31,5] - Capacities[5,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,10,7]
# 	    (expression: 0.519*P[5,10,7] - Capacities[5,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,2,5]
# 	    (expression: 0.14*P[2,2,5] - Capacities[2,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,35,2]
# 	    (expression: 3.2*P[1,35,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,40,7]
# 	    (expression: 0.3*P[3,40,7] - Capacities[3,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,14,3]
# 	    (expression: 0.94*P[3,14,3] - Capacities[3,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,42,5]
# 	    (expression: 0.14*P[1,42,5] - Capacities[1,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,44,8]
# 	    (expression: 0.519*P[3,44,8] - Capacities[3,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,44,8]
# 	    (expression: 0.519*P[1,44,8] - Capacities[1,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,15,6]
# 	    (expression: 0.46*P[1,15,6] - Capacities[1,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,37,7]
# 	    (expression: 0.519*P[2,37,7] - Capacities[2,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,43,9]
# 	    (expression: 0.94*P[1,43,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,11,5]
# 	    (expression: 0.14*P[5,11,5] - Capacities[5,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,9,4]
# 	    (expression: 0.3*P[4,9,4] - Capacities[4,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,41,3]
# 	    (expression: 0.94*P[3,41,3] - Capacities[3,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,13,5]
# 	    (expression: 0.14*P[5,13,5] - Capacities[5,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,8,4]
# 	    (expression: 0.519*P[1,8,4] - Capacities[1,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,19,7]
# 	    (expression: 0.3*P[3,19,7] - Capacities[3,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,1,8]
# 	    (expression: 0.3*P[5,1,8] - Capacities[5,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,33,1]
# 	    (expression: P[1,33,1] - Capacities[1,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,40,6]
# 	    (expression: 0.46*P[1,40,6] - Capacities[1,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,32,9]
# 	    (expression: 0.94*P[3,32,9] - Capacities[3,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,14,7]
# 	    (expression: 0.3*P[4,14,7] - Capacities[4,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,39,2]
# 	    (expression: 3.2*P[4,39,2] - Capacities[4,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,13,5]
# 	    (expression: 0.14*P[1,13,5] - Capacities[1,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,5,3]
# 	    (expression: 0.94*P[3,5,3] - Capacities[3,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,29,7]
# 	    (expression: 0.519*P[3,29,7] - Capacities[3,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,27,6]
# 	    (expression: 0.46*P[4,27,6] - Capacities[4,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,20,7]
# 	    (expression: 0.3*P[5,20,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,27,8]
# 	    (expression: 0.519*P[5,27,8] - Capacities[5,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,39,6]
# 	    (expression: 0.46*P[4,39,6] - Capacities[4,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,30,6]
# 	    (expression: 0.46*P[5,30,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,38,8]
# 	    (expression: 0.519*P[4,38,8] - Capacities[4,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,6,4]
# 	    (expression: 0.3*P[3,6,4] - Capacities[3,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,14,7]
# 	    (expression: 0.519*P[4,14,7] - Capacities[4,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,22,5]
# 	    (expression: 0.14*P[3,22,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,17,6]
# 	    (expression: 0.46*P[5,17,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,36,7]
# 	    (expression: 0.3*P[1,36,7] - Capacities[1,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,22,3]
# 	    (expression: 0.94*P[1,22,3] - Capacities[1,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,27,7]
# 	    (expression: 0.3*P[5,27,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,27,4]
# 	    (expression: 0.3*P[1,27,4] - Capacities[1,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,37,5]
# 	    (expression: 0.14*P[3,37,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,10,3]
# 	    (expression: 0.94*P[5,10,3] - Capacities[5,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,4,8]
# 	    (expression: 0.3*P[3,4,8] - Capacities[3,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,19,3]
# 	    (expression: 0.94*P[4,19,3] - Capacities[4,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,22,8]
# 	    (expression: 0.519*P[2,22,8] - Capacities[2,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,22,4]
# 	    (expression: 0.519*P[5,22,4] - Capacities[5,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,24,3]
# 	    (expression: 0.94*P[1,24,3] - Capacities[1,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,34,6]
# 	    (expression: 0.46*P[2,34,6] - Capacities[2,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,43,1]
# 	    (expression: P[2,43,1] - Capacities[2,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,2,5]
# 	    (expression: 0.14*P[4,2,5] - Capacities[4,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,37,4]
# 	    (expression: 0.519*P[2,37,4] - Capacities[2,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,33,9]
# 	    (expression: 0.94*P[2,33,9] - Capacities[2,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,38,3]
# 	    (expression: 0.94*P[1,38,3] - Capacities[1,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,38,8]
# 	    (expression: 0.519*P[2,38,8] - Capacities[2,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,31,8]
# 	    (expression: 0.3*P[2,31,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,32,5]
# 	    (expression: 0.14*P[2,32,5] - Capacities[2,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,43,3]
# 	    (expression: 0.94*P[4,43,3] - Capacities[4,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,41,2]
# 	    (expression: 3.2*P[2,41,2] - Capacities[2,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,27,2]
# 	    (expression: 3.2*P[4,27,2] - Capacities[4,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,40,3]
# 	    (expression: 0.94*P[4,40,3] - Capacities[4,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,5,8]
# 	    (expression: 0.3*P[4,5,8] - Capacities[4,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,32,6]
# 	    (expression: 0.46*P[5,32,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,26,7]
# 	    (expression: 0.519*P[1,26,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,41,7]
# 	    (expression: 0.3*P[5,41,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,34,9]
# 	    (expression: 0.94*P[5,34,9] - Capacities[5,9,3])
# ...
# 	    (expression: 0.94*P[4,37,9] - Capacities[4,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,32,4]
# 	    (expression: 0.3*P[5,32,4] - Capacities[5,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,24,9]
# 	    (expression: 0.94*P[2,24,9] - Capacities[2,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,23,2]
# 	    (expression: 3.2*P[4,23,2] - Capacities[4,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,29,5]
# 	    (expression: 0.14*P[1,29,5] - Capacities[1,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,4,4]
# 	    (expression: 0.519*P[2,4,4] - Capacities[2,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,4,2]
# 	    (expression: 3.2*P[1,4,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,45,9]
# 	    (expression: 0.94*P[3,45,9] - Capacities[3,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,45,9]
# 	    (expression: 0.94*P[1,45,9] - Capacities[1,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,11,6]
# 	    (expression: 0.46*P[4,11,6] - Capacities[4,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,36,6]
# 	    (expression: 0.46*P[2,36,6] - Capacities[2,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,4,7]
# 	    (expression: 0.3*P[5,4,7] - Capacities[5,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,42,1]
# 	    (expression: P[3,42,1] - Capacities[3,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,32,3]
# 	    (expression: 0.94*P[2,32,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,3,7]
# 	    (expression: 0.519*P[2,3,7] - Capacities[2,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,37,8]
# 	    (expression: 0.3*P[2,37,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,15,8]
# 	    (expression: 0.3*P[1,15,8] - Capacities[1,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,13,6]
# 	    (expression: 0.46*P[4,13,6] - Capacities[4,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,6,5]
# 	    (expression: 0.14*P[3,6,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,41,7]
# 	    (expression: 0.519*P[1,41,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,42,9]
# 	    (expression: 0.94*P[5,42,9] - Capacities[5,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,23,4]
# 	    (expression: 0.519*P[4,23,4] - Capacities[4,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,14,6]
# 	    (expression: 0.46*P[1,14,6] - Capacities[1,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,21,5]
# 	    (expression: 0.14*P[3,21,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,7,9]
# 	    (expression: 0.94*P[2,7,9] - Capacities[2,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,37,4]
# 	    (expression: 0.3*P[3,37,4] - Capacities[3,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,39,4]
# 	    (expression: 0.3*P[2,39,4] - Capacities[2,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,37,7]
# 	    (expression: 0.3*P[4,37,7] - Capacities[4,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,3,3]
# 	    (expression: 0.94*P[4,3,3] - Capacities[4,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,28,2]
# 	    (expression: 3.2*P[4,28,2] - Capacities[4,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,23,8]
# 	    (expression: 0.3*P[5,23,8] - Capacities[5,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,31,7]
# 	    (expression: 0.519*P[5,31,7] - Capacities[5,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,2,5]
# 	    (expression: 0.14*P[5,2,5] - Capacities[5,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,20,2]
# 	    (expression: 3.2*P[1,20,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,2,4]
# 	    (expression: 0.3*P[5,2,4] - Capacities[5,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,35,8]
# 	    (expression: 0.3*P[3,35,8] - Capacities[3,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,18,5]
# 	    (expression: 0.14*P[5,18,5] - Capacities[5,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,30,7]
# 	    (expression: 0.3*P[4,30,7] - Capacities[4,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,44,1]
# 	    (expression: P[2,44,1] - Capacities[2,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,39,6]
# 	    (expression: 0.46*P[3,39,6] - Capacities[3,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,33,8]
# 	    (expression: 0.3*P[4,33,8] - Capacities[4,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,4,2]
# 	    (expression: 3.2*P[2,4,2] - Capacities[2,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,26,9]
# 	    (expression: 0.94*P[3,26,9] - Capacities[3,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,35,4]
# 	    (expression: 0.519*P[3,35,4] - Capacities[3,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,32,4]
# 	    (expression: 0.3*P[2,32,4] - Capacities[2,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,40,4]
# 	    (expression: 0.3*P[1,40,4] - Capacities[1,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,24,3]
# 	    (expression: 0.94*P[4,24,3] - Capacities[4,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,28,7]
# 	    (expression: 0.3*P[2,28,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,16,6]
# 	    (expression: 0.46*P[5,16,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,19,3]
# 	    (expression: 0.94*P[1,19,3] - Capacities[1,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,30,7]
# 	    (expression: 0.519*P[4,30,7] - Capacities[4,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,4,8]
# 	    (expression: 0.3*P[2,4,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,36,7]
# 	    (expression: 0.519*P[3,36,7] - Capacities[3,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,15,7]
# 	    (expression: 0.519*P[1,15,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,36,1]
# 	    (expression: P[1,36,1] - Capacities[1,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,27,4]
# 	    (expression: 0.3*P[4,27,4] - Capacities[4,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,32,8]
# 	    (expression: 0.519*P[2,32,8] - Capacities[2,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,43,5]
# 	    (expression: 0.14*P[4,43,5] - Capacities[4,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,41,7]
# 	    (expression: 0.3*P[2,41,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,22,5]
# 	    (expression: 0.14*P[2,22,5] - Capacities[2,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,43,4]
# 	    (expression: 0.3*P[4,43,4] - Capacities[4,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,35,6]
# 	    (expression: 0.46*P[2,35,6] - Capacities[2,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,33,7]
# 	    (expression: 0.519*P[5,33,7] - Capacities[5,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,27,6]
# 	    (expression: 0.46*P[1,27,6] - Capacities[1,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,5,3]
# 	    (expression: 0.94*P[2,5,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,44,8]
# 	    (expression: 0.3*P[4,44,8] - Capacities[4,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,39,8]
# 	    (expression: 0.519*P[2,39,8] - Capacities[2,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,13,5]
# 	    (expression: 0.14*P[4,13,5] - Capacities[4,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,30,8]
# 	    (expression: 0.519*P[5,30,8] - Capacities[5,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,35,8]
# 	    (expression: 0.3*P[4,35,8] - Capacities[4,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,45,8]
# 	    (expression: 0.3*P[1,45,8] - Capacities[1,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,43,3]
# 	    (expression: 0.94*P[2,43,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,19,7]
# 	    (expression: 0.3*P[2,19,7] - Capacities[2,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,25,5]
# 	    (expression: 0.14*P[1,25,5] - Capacities[1,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,9,9]
# 	    (expression: 0.94*P[5,9,9] - Capacities[5,9,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,9,4]
# 	    (expression: 0.3*P[1,9,4] - Capacities[1,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,40,4]
# 	    (expression: 0.3*P[3,40,4] - Capacities[3,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,1,8]
# 	    (expression: 0.519*P[5,1,8] - Capacities[5,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,4,7]
# 	    (expression: 0.519*P[1,4,7] - Capacities[1,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,22,8]
# 	    (expression: 0.3*P[3,22,8] - Capacities[3,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,33,5]
# 	    (expression: 0.14*P[4,33,5] - Capacities[4,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,14,3]
# 	    (expression: 0.94*P[2,14,3] - Capacities[2,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,14,8]
# 	    (expression: 0.3*P[5,14,8] - Capacities[5,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,21,7]
# 	    (expression: 0.519*P[5,21,7] - Capacities[5,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,6,4]
# 	    (expression: 0.3*P[5,6,4] - Capacities[5,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,2,5]
# 	    (expression: 0.14*P[3,2,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,5,6]
# 	    (expression: 0.46*P[5,5,6] - Capacities[5,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,11,4]
# 	    (expression: 0.519*P[5,11,4] - Capacities[5,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,41,2]
# 	    (expression: 3.2*P[1,41,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,10,6]
# 	    (expression: 0.46*P[1,10,6] - Capacities[1,6,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,17,5]
# 	    (expression: 0.14*P[3,17,5] - Capacities[3,5,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[5,6,8]
# 	    (expression: 0.519*P[5,6,8] - Capacities[5,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,33,4]
# 	    (expression: 0.3*P[3,33,4] - Capacities[3,4,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,31,7]
# 	    (expression: 0.519*P[2,31,7] - Capacities[2,7,3])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,17,8]
# 	    (expression: 0.3*P[2,17,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,22,2]
# 	    (expression: 3.2*P[1,22,2] - Capacities[1,2,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,13,1]
# 	    (expression: P[3,13,1] - Capacities[3,1,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[1,15,7]
# 	    (expression: 0.3*P[1,15,7] - Capacities[1,7,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,15,8]
# 	    (expression: 0.3*P[2,15,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,34,3]
# 	    (expression: 0.94*P[3,34,3] - Capacities[3,3,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,40,4]
# 	    (expression: 0.519*P[3,40,4] - Capacities[3,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[4,25,4]
# 	    (expression: 0.519*P[4,25,4] - Capacities[4,4,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[3,5,8]
# 	    (expression: 0.519*P[3,5,8] - Capacities[3,8,2])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,34,8]
# 	    (expression: 0.3*P[2,34,8] - Capacities[2,8,1])
# ERROR: evaluating expression: No value for uninitialized NumericValue object P[2,26,2]
# 	    (expression: 3.2*P[2,26,2] - Capacities[2,2,2])
#     Key : Lower : Body : Upper
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-2e16ad56ea3c> in <module>()
# ----> 1 model.capacityConst.display()
#
# C:\Anaconda\envs\py35\lib\site-packages\pyomo\core\base\constraint.py in display(self, prefix, ostream)
#     806                         ((k,v) for k,v in iteritems(self._data) if v.active),
#     807                         ( "Lower","Body","Upper" ),
# --> 808                         lambda k, v: [ value(v.lower),
#     809                                        v.body(),
#     810                                        value(v.upper),
#
# C:\Anaconda\envs\py35\lib\site-packages\pyomo\core\base\misc.py in tabular_writer(ostream, prefix, data, header, row_generator)
#     179                 prefix
#     180                 + " : ".join( _width[i] % x for i,x in enumerate(_data) )
# --> 181                 + "\n")
#     182
#
# C:\Anaconda\envs\py35\lib\site-packages\pyomo\core\base\misc.py in <genexpr>(.0)
#     178             ostream.write(
#     179                 prefix
# --> 180                 + " : ".join( _width[i] % x for i,x in enumerate(_data) )
#     181                 + "\n")
#     182
#
# TypeError: not all arguments converted during string formatting

# %%
#-----------------------------------------------------------------------------#
## GLobal constraints
#-----------------------------------------------------------------------------#
def MultipleloadsBalance_rule(model, i,  t, out):
    return (model.loads[i, t,out] + model.Pexport[i, t,out] <= ((model.Qout[ i, t,out] - model.Qin[i, t,out] + 
                                                        sum(model.P[i, t,inp]*model.cMatrix[inp,out] for inp in model.In) 
                                                                + sum(model.DH_Q[j,i,t,out]*(1-model.Losses[i,j])- model.DH_Q[i,j,t,out] for j in model.hub_i ))))

def loadsBalance_rule(model, i, t, out):
    return (model.loads[i, t,out] + model.Pexport[i, t,out] <= (model.Qout[ i, t,out] - model.Qin[i, t,out] + 
                                                        sum(model.P[i, t,inp]*model.cMatrix[inp,out] for inp in model.In)))

if numberofhubs>1:
    model.loadsBalance = Constraint(model.hub_i,  model.Time, model.Out, rule=MultipleloadsBalance_rule)
    '''
    model.DHcon = ConstraintList()
    for i in range(1, numberofhubs+1):
        for t in range(1,data.DemandData.shape[1]+1):
            for out in range(1,data.numberofdemands+1):
                gen = (j for j in model.hub_i if j!=i)
                model.DHcon.add((model.loads[i, t,out] + model.Pexport[i, t,out]) <= ((model.Qout[ i, t,out] - model.Qin[i, t,out] + 
                                                        sum(model.P[i, t,inp]*model.cMatrix[inp,out] for inp in model.In) 
                                                        + sum(model.DH_Q[j,i,t,out]*model.Losses[i,j]- model.DH_Q[i,j,t,out] for j in gen))))

    '''
    
    
else:
    model.loadsBalance = Constraint(model.hub_i, model.Time, model.Out, rule=loadsBalance_rule)

def capacityConst_rule(model, i, t, inp, out):
    if model.cMatrix[inp,out] <= 0:
        return(Constraint.Skip)
    else:
        return (model.P[i, t, inp]  * model.cMatrix[inp,out]<= model.Capacities[i, inp,out])
model.capacityConst = Constraint(model.hub_i, model.Time, model.In, model.Out, rule=capacityConst_rule)


def maxCapacity_rule2(model, i, tech, out):
    return (model.Capacities[i, tech, out] <= model.maxCapTechsAll[i, tech])
model.maxCapacity2 = Constraint(model.hub_i, model.Techs, model.Out, rule=maxCapacity_rule2)


'''
def carbonConst_rule(model):
    return (model.TotalCarbon <= model.maxCarbon)
model.carbonConst = Constraint(rule=carbonConst_rule)
'''
# Out:
# '\ndef carbonConst_rule(model):\n    return (model.TotalCarbon <= model.maxCarbon)\nmodel.carbonConst = Constraint(rule=carbonConst_rule)\n'

# %%
#-----------------------------------------------------------------------------#
## Specific constraints 
#-----------------------------------------------------------------------------#

def partLoadL_rule(model, i, t, disp, out):  
    if model.cMatrix[disp,out] <= 0:
        return(Constraint.Skip)
    else:
        return (model.partLoad[disp, out] * model.Capacities[i, disp, out] <= 
                                                                    (model.P[i, disp, out] * model.cMatrix[disp,out] 
                                                                    + model.bigM * (1 - model.Yon[i, t, disp])))
model.partLoadL = Constraint(model.hub_i, model.Time, model.PartLoad, model.Out, rule=partLoadL_rule)

def partLoadU_rule(model, i, t, disp, out):    
    if model.cMatrix[disp,out] <= 0:
        return(Constraint.Skip)
    else:
        return (model.P[i, t, disp] * model.cMatrix[disp, out] <= model.bigM * model.Yon[i, t, disp])
model.partLoadU = Constraint(model.hub_i, model.Time, model.PartLoad, model.Out, rule=partLoadU_rule)



def solarInput_rule(model, i, t, sol, out):
    if model.cMatrix[sol, out] <= 0:
        return(Constraint.Skip)
    else:
        return (model.P[i, t, sol] == model.solarEm[t] * model.Capacities[i, sol, out])
model.solarInput = Constraint(model.hub_i, model.Time, model.SolarTechs, model.Out, rule=solarInput_rule) 


def roofArea_rule(model,i, roof, demand):
    return (sum(model.Capacities[i, roof,d] for d in number_of_demands) <= model.maxSolarArea) #DemandData.shape[1]
model.roofArea = Constraint(model.hub_i, model.roof_tech,model.Out,rule=roofArea_rule) #model.roof_tech

def fixCostConst_rule(model, i, inp, out):
    return (model.Capacities[i, inp,out] <= model.bigM * model.Ytechnologies[i, inp,out])
model.fixCostConst = Constraint(model.hub_i, model.In, model.Out, rule=fixCostConst_rule)

dispatch_demands=data.DisDemands() 
CHP_list=data.CHP_list()
model.con = ConstraintList()
for i in range(1, numberofhubs+1):
    for x in range(1, len(dispatch_demands)+1):
        model.con.add(model.Capacities[i, CHP_list[x-1],dispatch_demands[x-1,1]] == model.cMatrix[CHP_list[x-1],dispatch_demands[x-1,1]] / model.cMatrix[CHP_list[x-1],dispatch_demands[x-1,0]] * model.Capacities[i, CHP_list[x-1],dispatch_demands[x-1,0]])
        model.con.add(model.Ytechnologies[i, CHP_list[x-1],dispatch_demands[x-1,0]]==model.Ytechnologies[i, CHP_list[x-1],dispatch_demands[x-1,1]])
        model.con.add(model.Capacities[i, CHP_list[x-1],dispatch_demands[x-1,0]] <= model.maxCapTechs[i, CHP_list[x-1]] * model.Ytechnologies[i, CHP_list[x-1],dispatch_demands[x-1,0]])

#model.con.construct()



def DH_rule(model, i, j, t, out):
    return (model.DH_Q[i,j,t,out] <= model.Ypipeline[i,j] * model.bigM)

if numberofhubs>1:
    model.DH_network = Constraint(model.hub_i, model.hub_j, model.Time, model.Out, rule=DH_rule)
    
#def DHy_rule(model, i, j):
#    return (model.Ypipeline[i,j]+model.Ypipeline[j,i] <= 1)

if numberofhubs>1:
    #model.DH_network = Constraint(model.hub_i, model.hub_j,  rule=DHy_rule)
    model.DHYcon = ConstraintList()
    for i in range(1, numberofhubs+1-1):
        model.DHYcon.add((model.Ypipeline[i,i]<= 0 ))
        for j in range(i+1, numberofhubs+1):
                model.DHYcon.add((model.Ypipeline[j,j]<= 0 ))
                model.DHYcon.add((model.Ypipeline[i,j]+model.Ypipeline[j,i] <= 1 ))
            #else:
                #model.DHYcon.add((model.Ypipeline[i,j]+model.Ypipeline[j,i] == 0 ))

# %%
#-----------------------------------------------------------------------------#
## Storage constraints
#-----------------------------------------------------------------------------#

def storageBalance_rule(model, i, t, out):
    return (model.E[i, t, out] == (model.lossesStorStanding[i,out] * model.E[i, (t-1), out] 
                                + model.chargingEff[i,out] * model.Qin[i, t, out] 
                                - (1/model.dischLosses[i,out]) * model.Qout[i, t, out]))
model.storageBalance = Constraint(model.hub_i, model.SubTime, model.Out, rule=storageBalance_rule)
'''
model.StorCon = ConstraintList()
for x in range(1, DemandData.shape[1]+1):
    
    #model.StorCon.add(model.E[1, x] == model.StorageCap[x] * model.minSoC[x])
    model.StorCon.add(model.E[1, x] == model.E[8760, x])
    #model.StorCon.add(model.Qout[1, x] == 0)
'''    

'''
def storageInitBattery_rule(model):
    return (model.E[1, 1] == model.StorageCap[1] * model.minSoC[1])
model.storageInitBattery = Constraint(rule=storageInitBattery_rule)

def storageInitThermal1_rule(model):
    return (model.E[1, 2] == model.E[8760, 2])
model.storageInitThermal1 = Constraint(rule=storageInitThermal1_rule)

def storageInitThermal2_rule(model):
    return (model.Qout[1, 2] == 0)
model.storageInitThermal2 = Constraint(rule=storageInitThermal2_rule)
'''


def storageChargeRate_rule(model, i, t, out):
    return (model.Qin[i, t,out] <= model.maxStorCh[i, out] * model.StorageCap[i, out])
model.storageChargeRate = Constraint(model.hub_i, model.Time, model.Out, rule=storageChargeRate_rule)

def storageDischRate_rule(model, i, t, out):
    return (model.Qout[i, t,out] <= model.maxStorDisch[i,out] * model.StorageCap[i, out])
model.storageDischRate = Constraint(model.hub_i,model.Time, model.Out, rule=storageDischRate_rule)
'''
def storageMinState_rule(model, t, out):
    return (model.E[t,out] >= model.StorageCap[out] * model.minSoC[out])
model.storageMinState = Constraint(model.Time, model.Out, rule=storageMinState_rule)
'''

def storageCap_rule(model, i, t, out):
    return (model.E[i, t,out] <= model.StorageCap[i, out] )
model.storageCap = Constraint(model.hub_i,model.Time, model.Out, rule=storageCap_rule)

def storageMaxCap_rule(model, i,  out):
    return (model.StorageCap[i, out] <= model.bigM * model.Ystorage[i,out] )
model.storageMaxCap = Constraint(model.hub_i,  model.Out, rule=storageMaxCap_rule)

# %%
#-----------------------------------------------------------------------------#
## Objective functions
#-----------------------------------------------------------------------------#
def objective_rule(model):
    return (model.TotalCost)
model.Total_Cost = Objective(rule=objective_rule, sense=minimize)

#def objective_rule(model):
#    return (model.TotalCarbon2)
#model.Total_Carbon = Objective(rule=objective_rule, sense=minimize)

def opCost_rule(model):
    return(model.OpCost == ((sum (model.opPrices[inp] 
                            * sum(model.P[i, t,inp] for i in model.hub_i for t in model.Time)
                            for inp in model.In)))
                            )
model.opCost = Constraint(rule=opCost_rule) 

def maintenanceCost_rule(model):
    return(model.MaintCost == (sum(model.P[i, t,inp] * 
                              model.cMatrix[inp,out] * model.omvCosts[i, inp]
                              for i in model.hub_i for t in model.Time for inp in model.In for out in model.Out)
                              ))
model.maintCost = Constraint(rule=maintenanceCost_rule)

def incomeExp_rule(model):
    return(model.IncomeExp == (sum(model.feedInTariffs[out] * 
                            sum(model.Pexport[i, t,out] for i in model.hub_i for t in model.Time) 
                            for out in model.Out))
                            )
model.incomeExp = Constraint(rule=incomeExp_rule)

def DHinvCost_rule(model):
    return(model.InvCost == (sum(model.NetPresentValueTech[inp] * (model.linCapCosts[i, inp,out] * model.Capacities[i, inp,out] ) for i in model.hub_i for inp in model.Techs for out in model.Out) #+ model.fixCapCosts[inp,out] * model.Ytechnologies[inp,out]
                            + sum(model.NetPresentValueStor[out] * model.linStorageCosts[i, out] * model.StorageCap[i, out] for i in model.hub_i for out in model.Out)))
                               #+ sum(model.Distance[i,j]*model.PipeCost*model.Ypipeline[i,j] for i in model.hub_i for j in model.hub_j))

def invCost_rule(model):
    return(model.InvCost == (sum(model.NetPresentValueTech[inp] * (model.linCapCosts[i, inp,out] * model.Capacities[i, inp,out] ) for i in model.hub_i for inp in model.Techs for out in model.Out) #+ model.fixCapCosts[inp,out] * model.Ytechnologies[inp,out]
                            + sum(model.NetPresentValueStor[out] * model.linStorageCosts[i, out] * model.StorageCap[i, out] for i in model.hub_i for out in model.Out)
                            ))

if numberofhubs>1:
    model.invCost = Constraint(rule=DHinvCost_rule) 
else:
    model.invCost = Constraint(rule=invCost_rule) 

def totalCost_rule(model):
    return(model.TotalCost == model.InvCost + model.OpCost + model.MaintCost - model.IncomeExp)
model.totalCost = Constraint(rule=totalCost_rule) 

def totalCarbon2_rule(model):
    return(model.TotalCarbon2 == model.TotalCarbon)
model.totalCarbon2 = Constraint(rule=totalCarbon2_rule)

def totalCarbon_rule(model):
    return(model.TotalCarbon == sum(model.carbonFactors[inp] * sum(model.P[i, t,inp] for i in model.hub_i for t in model.Time) for inp in model.In))
model.totalCarbon = Constraint(rule=totalCarbon_rule)

# %%
#-----------------------------------------------------------------------------#
## Print model ##
#-----------------------------------------------------------------------------#
#model.pprint()

#instance = model.create(r'C:\Users\mobo\OneDrive\0PhD\Python-based energy hub\Generic_energy_hub_PYTHON\generic_model.dat')


opt = SolverFactory("gurobi")
opt.options["mipgap"]=0.05
opt.options["FeasibilityTol"]=1e-05
solver_manager = SolverManagerFactory("serial")
#results = solver_manager.solve(instance, opt=opt, tee=True,timelimit=None, mipgap=0.1)

results = solver_manager.solve(model, opt=opt, tee=True,timelimit=None)

#sends results to stdout
#results.write()


def pyomo_save_results(options=None, instance=None, results=None):
    OUTPUT = open(r'C:\Users\mobo\OneDrive\0PhD\Python-based energy hub\Generic_energy_hub_PYTHON\data\Results_generic_hub.txt','w')
    print(results, file=OUTPUT)
    OUTPUT.close()
#pyomo_save_results(instance=instance, results=results)    

#Example of how to print variables
#print(instance.TotalCost.value)
print(model.TotalCost.value)




#for i in instance.Pnaturalgas:
#    print (instance.Pnaturalgas[i], instance.Pnaturalgas[i].value)

#print("--- %s seconds ---" % (time.time() - start_time))

## create the instance
#instance = model.create(’DiseaseEstimation.dat’)
## define the solver and its options
#solver = ’ipopt’
#opt = SolverFactory( solver )
#if opt is None:
#raise ValueError, "Problem constructing solver \
#‘"+str(solver)
#opt.set_options(’max_iter=2’)
## create the solver manager
#solver_manager = SolverManagerFactory( ’serial’ )
## solve
#results = solver_manager.solve(instance, opt=opt, tee=True,\
#timelimit=None)
#instance.load(results)
## display results
#display(instance)
# Out:
# Changed value of parameter MIPGap to 0.05
#    Prev: 0.0001  Min: 0.0  Max: 1e+100  Default: 0.0001
# Parameter mipgap unchanged
#    Value: 0.05  Min: 0.0  Max: 1e+100  Default: 0.0001
# Changed value of parameter FeasibilityTol to 1e-05
#    Prev: 1e-06  Min: 1e-09  Max: 0.01  Default: 1e-06
# Optimize a model with 12962 rows, 9093 columns and 43066 nonzeros
# Variable types: 8258 continuous, 835 integer (835 binary)
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+03]
# Presolve removed 4364 rows and 2367 columns
# Presolve time: 0.17s
# Presolved: 8598 rows, 6726 columns, 27099 nonzeros
# Variable types: 6176 continuous, 550 integer (550 binary)
#
# Root relaxation: objective 1.728536e+04, 3446 iterations, 0.08 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    17285.357719 17285.3577  0.00%     -    0s
#
# Explored 0 nodes (3446 simplex iterations) in 0.33 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 17285.4
# Pool objective bound 17285.4
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 1.728535771942e+04, best bound 1.728535771942e+04, gap 0.0000%
# 17285.3577194

# %%
print(model.TotalCarbon.value)
# Out:
# 1859.59884795

# %%
model.P.get_values()
# Out:
# {(1, 1, 1): 3.0,
#  (1, 1, 2): 0.0,
#  (1, 1, 3): 22.3404255319,
#  (1, 1, 4): 0.0,
#  (1, 1, 5): 0.0,
#  (1, 1, 6): 0.0,
#  (1, 1, 7): 0.0,
#  (1, 1, 8): 0.0,
#  (1, 1, 9): 22.3404255319,
#  (1, 2, 1): 3.0,
#  (1, 41, 1): 22.0,
#  (1, 41, 2): 0.0,
#  (1, 41, 3): 30.8510638298,
#  (1, 41, 4): 0.0,
#  (1, 41, 5): 0.0,
#  (1, 41, 6): 0.0,
#  (1, 41, 7): 0.0,
#  (1, 41, 8): 0.0,
#  (1, 41, 9): 30.8510638298,
#  (1, 42, 1): 22.0,
#  (1, 42, 2): 0.0,
#  (1, 42, 3): 43.6170212766,
#  (1, 42, 4): 0.0,
#  (1, 42, 5): 0.0,
#  (1, 42, 6): 0.0,
#  (1, 42, 7): 0.0,
#  (1, 42, 8): 0.0,
#  (1, 42, 9): 43.6170212766,
#  (1, 43, 1): 28.0,
#  (1, 43, 2): 0.0,
#  (1, 43, 3): 35.1063829787,
#  (1, 43, 4): 0.0,
#  (1, 43, 5): 0.0,
#  (1, 43, 6): 0.0,
#  (1, 43, 7): 0.0,
#  (1, 43, 8): 0.0,
#  (1, 43, 9): 35.1063829787,
#  (1, 44, 1): 27.0,
#  (1, 44, 2): 0.0,
#  (1, 44, 3): 39.3617021277,
#  (1, 44, 4): 0.0,
#  (1, 44, 5): 0.0,
#  (1, 44, 6): 0.0,
#  (1, 44, 7): 0.0,
#  (1, 44, 8): 0.0,
#  (1, 44, 9): 39.3617021277,
#  (1, 45, 1): 27.0,
#  (1, 45, 2): 0.0,
#  (1, 45, 3): 44.6808510638,
#  (1, 45, 4): 0.0,
#  (1, 45, 5): 0.0,
#  (1, 45, 6): 0.0,
#  (1, 45, 7): 0.0,
#  (1, 45, 8): 0.0,
#  (1, 45, 9): 44.6808510638,
#  (2, 1, 1): 0.0,
#  (2, 1, 2): 0.0,
#  (2, 1, 3): 22.3404255319,
#  (2, 1, 4): 0.0,
#  (2, 1, 5): 0.0,
#  (2, 1, 6): 0.0,
#  (2, 1, 7): 40.4624277457,
#  (2, 1, 8): 0.0,
#  (2, 1, 9): 0.0,
#  (2, 2, 1): 0.0,
#  (2, 2, 2): 0.0,
#  (2, 2, 3): 25.5319148936,
#  (2, 2, 4): 0.0,
#  (2, 2, 5): 0.0,
#  (2, 2, 6): 0.0,
#  (2, 2, 7): 46.2427745665,
#  (2, 2, 8): 0.0,
#  (2, 2, 9): 0.0,
#  (2, 3, 1): 0.0,
#  (2, 3, 2): 0.0,
#  (2, 3, 3): 27.6595744681,
#  (2, 3, 4): 0.0,
#  (2, 3, 5): 0.0,
#  (2, 3, 6): 0.0,
#  (2, 3, 7): 50.0963391137,
#  (2, 3, 8): 0.0,
#  (2, 3, 9): 0.0,
#  (2, 4, 1): 0.0,
#  (2, 4, 2): 0.0,
#  (2, 4, 3): 29.7872340426,
#  (2, 4, 4): 0.0,
#  (2, 4, 5): 0.0,
#  (2, 4, 6): 0.0,
#  (2, 4, 7): 53.9499036609,
#  (2, 4, 8): 0.0,
#  (2, 4, 9): 0.0,
#  (2, 5, 1): 0.0,
#  (2, 5, 2): 0.0,
#  (2, 5, 3): 31.914893617,
#  (2, 5, 4): 0.0,
#  (2, 5, 5): 0.0,
#  (2, 5, 6): 0.0,
#  (2, 44, 4): 0.0,
#  (2, 44, 5): 0.0,
#  (2, 44, 6): 0.0,
#  (2, 44, 7): 71.2909441233,
#  (2, 44, 8): 0.0,
#  (2, 44, 9): 0.0,
#  (2, 45, 1): 2.7225433526,
#  (2, 45, 2): 0.0,
#  (2, 45, 3): 44.6808510638,
#  (2, 45, 4): 0.0,
#  (2, 45, 5): 0.0,
#  (2, 45, 6): 0.0,
#  (2, 45, 7): 80.9248554913,
#  (2, 45, 8): 0.0,
#  (2, 45, 9): 0.0}

# %%
model.Capacities.get_values()
# Out:
# {(1, 1, 1): 5000.0,
#  (1, 1, 2): 0.0,
#  (1, 1, 3): 0.0,
#  (1, 2, 1): 0.0,
#  (1, 2, 2): 0.0,
#  (1, 2, 3): 0.0,
#  (1, 3, 1): 0.0,
#  (1, 3, 2): 82.0,
#  (1, 3, 3): 0.0,
#  (1, 4, 1): 0.0,
#  (1, 4, 2): 0.0,
#  (1, 4, 3): 0.0,
#  (1, 5, 1): 0.0,
#  (1, 5, 2): 0.0,
#  (1, 5, 3): 0.0,
#  (1, 6, 1): 0.0,
#  (1, 6, 2): 0.0,
#  (1, 6, 3): 0.0,
#  (1, 7, 1): 0.0,
#  (1, 7, 2): 0.0,
#  (1, 7, 3): 0.0,
#  (1, 8, 1): 0.0,
#  (1, 8, 2): 0.0,
#  (1, 8, 3): 0.0,
#  (1, 9, 1): 0.0,
#  (1, 9, 2): 0.0,
#  (1, 9, 3): 118.012012012,
#  (2, 1, 1): 5000.0,
#  (2, 1, 2): 0.0,
#  (2, 1, 3): 0.0,
#  (2, 2, 1): 0.0,
#  (2, 2, 2): 0.0,
#  (2, 2, 3): 0.0,
#  (2, 3, 1): 0.0,
#  (2, 3, 2): 82.0,
#  (2, 3, 3): 0.0,
#  (2, 4, 1): 0.0,
#  (2, 4, 2): 0.0,
#  (2, 4, 3): 0.0,
#  (2, 5, 1): 0.0,
#  (2, 5, 2): 0.0,
#  (2, 5, 3): 0.0,
#  (2, 6, 1): 0.0,
#  (2, 6, 2): 0.0,
#  (2, 6, 3): 0.0,
#  (2, 7, 1): 0.0,
#  (2, 7, 2): 0.0,
#  (2, 7, 3): 0.0,
#  (2, 8, 1): 0.0,
#  (2, 8, 2): 0.0,
#  (2, 8, 3): 0.0,
#  (2, 9, 1): 0.0,
#  (2, 9, 2): 0.0,
#  (2, 9, 3): 82.0,
#  (3, 1, 1): 5000.0,
#  (3, 1, 2): 0.0,
#  (3, 1, 3): 0.0,
#  (3, 2, 1): 0.0,
#  (3, 2, 2): 0.0,
#  (3, 2, 3): 0.0,
#  (3, 3, 1): 0.0,
#  (3, 3, 2): 82.0,
#  (3, 3, 3): 0.0,
#  (3, 4, 1): 0.0,
#  (3, 4, 2): 0.0,
#  (3, 4, 3): 0.0,
#  (3, 5, 1): 0.0,
#  (3, 5, 2): 0.0,
#  (3, 5, 3): 0.0,
#  (3, 6, 1): 0.0,
#  (3, 6, 2): 0.0,
#  (3, 6, 3): 0.0,
#  (3, 7, 1): 0.0,
#  (4, 2, 1, 3): 0.0,
#  (5, 2, 21, 2): 0.0,
#  (1, 2, 14, 2): 0.0,
#  (4, 4, 11, 1): 0.0,
#  (5, 1, 33, 1): 0.0,
#  (3, 3, 21, 3): 0.0,
#  (1, 1, 27, 2): 0.0,
#  (1, 5, 6, 3): 0.0,
#  (4, 1, 28, 2): 0.0,
#  (3, 2, 2, 3): 0.0,
#  (5, 3, 21, 1): 0.0,
#  (5, 3, 30, 1): 0.0,
#  (1, 4, 7, 2): 0.0,
#  (1, 2, 27, 3): 0.0,
#  (5, 5, 25, 1): 0.0,
#  (3, 4, 33, 1): 0.0,
#  (4, 4, 33, 1): 0.0,
#  (2, 1, 4, 2): 0.0,
#  (1, 1, 45, 3): 0.0,
#  (1, 1, 22, 3): 0.0,
#  (5, 2, 1, 1): 0.0,
#  (4, 5, 12, 2): 0.0,
#  (2, 2, 32, 3): 0.0,
#  (3, 2, 45, 1): 0.0,
#  (3, 2, 15, 2): 0.0,
#  (2, 4, 1, 3): 0.0,
#  (1, 4, 5, 1): 0.0,
#  (3, 1, 42, 3): 0.0,
#  (3, 5, 7, 1): 0.0,
#  (5, 2, 22, 3): 0.0,
#  (5, 2, 45, 3): 0.0,
#  (2, 5, 30, 3): 0.0,
#  (2, 1, 33, 1): 0.0,
#  (2, 1, 3, 2): 0.0,
#  (5, 5, 38, 1): 0.0,
#  (5, 1, 27, 3): 0.0,
#  (2, 2, 38, 3): 0.0,
#  (5, 5, 32, 2): 0.0,
#  (5, 3, 22, 2): 0.0,
#  (1, 5, 5, 2): 0.0,
#  (1, 5, 39, 1): 0.0,
#  (1, 1, 43, 1): 0.0,
#  (2, 4, 28, 2): 0.0,
#  (5, 3, 33, 2): 0.0,
#  (4, 2, 34, 2): 0.0,
#  (3, 5, 40, 1): 0.0,
#  (5, 2, 27, 2): 0.0,
#  (2, 5, 43, 2): 0.0,
#  (1, 2, 33, 1): 0.0,
#  (5, 1, 14, 2): 0.0,
#  (1, 1, 21, 2): 0.0,
#  (3, 3, 20, 1): 0.0,
#  (1, 5, 24, 3): 0.0,
#  (4, 1, 2, 2): 0.0,
#  (3, 2, 12, 3): 0.0,
#  (5, 3, 20, 3): 0.0,
#  (1, 3, 15, 1): 0.0,
#  (5, 2, 12, 1): 0.0,
#  (4, 3, 45, 2): 0.0,
#  (4, 4, 32, 3): 0.0,
#  (2, 2, 12, 1): 0.0,
#  (1, 1, 44, 1): 0.0,
#  (4, 5, 24, 1): 0.0,
#  (5, 4, 3, 2): 0.0,
#  (2, 5, 11, 3): 0.0,
#  (4, 2, 33, 3): 0.0,
#  (2, 5, 40, 3): 0.0,
#  (5, 2, 23, 1): 0.0,
#  (2, 1, 21, 2): 0.0,
#  (4, 3, 22, 3): 0.0,
#  (5, 1, 13, 3): 0.0,
#  (3, 3, 14, 3): 0.0,
#  (4, 5, 39, 3): 0.0,
#  (2, 5, 4, 1): 0.0,
#  (1, 5, 38, 3): 0.0,
#  (2, 3, 15, 3): 0.0,
#  (3, 2, 38, 1): 0.0,
#  (4, 2, 25, 2): 0.0,
#  (3, 5, 3, 3): 0.0,
#  (5, 2, 41, 1): 0.0,
#  (2, 5, 18, 1): 0.0,
#  (3, 1, 30, 2): 0.0,
#  (4, 3, 14, 2): 0.0,
#  (4, 3, 43, 2): 0.0,
#  (3, 3, 45, 2): 0.0,
#  (2, 2, 44, 2): 0.0,
#  (3, 2, 26, 2): 0.0,
#  (5, 3, 15, 1): 0.0,
#  (4, 2, 12, 3): 0.0,
#  (2, 5, 9, 1): 0.0,
#  (4, 4, 27, 1): 0.0,
#  (2, 2, 23, 3): 0.0,
#  (5, 1, 44, 1): 0.0,
#  (3, 3, 24, 3): 0.0,
#  (4, 4, 35, 1): 0.0,
#  (2, 3, 40, 3): 0.0,
#  (3, 2, 7, 3): 0.0,
#  (1, 4, 43, 1): 0.0,
#  (2, 4, 43, 1): 0.0,
#  (2, 5, 6, 2): 0.0,
#  (1, 2, 28, 3): 0.0,
#  (5, 5, 28, 1): 0.0,
#  (4, 4, 36, 1): 0.0,
#  (5, 1, 19, 2): 0.0,
#  (1, 1, 32, 3): 0.0,
#  (1, 5, 13, 1): 0.0,
#  (5, 4, 2, 1): 0.0,
#  (2, 4, 4, 3): 0.0,
#  (1, 3, 30, 2): 0.0,
#  (3, 1, 45, 3): 0.0,
#  (3, 5, 2, 1): 0.0,
#  (3, 5, 32, 2): 0.0,
#  (5, 2, 19, 3): 0.0,
#  (2, 5, 19, 3): 0.0,
#  (1, 2, 41, 2): 0.0,
#  (4, 3, 18, 1): 0.0,
#  (5, 5, 11, 2): 0.0,
#  (4, 5, 11, 3): 0.0,
#  (5, 1, 6, 3): 0.0,
#  (2, 2, 33, 3): 0.0,
#  (5, 4, 33, 2): 0.0,
#  (1, 5, 34, 1): 0.0,
#  (4, 1, 26, 1): 0.0,
#  (3, 2, 4, 2): 0.0,
#  (5, 1, 18, 1): 0.0,
#  (3, 1, 24, 2): 0.0,
#  (5, 2, 38, 1): 0.0,
#  (4, 3, 37, 3): 0.0,
#  (3, 2, 10, 1): 0.0,
#  (5, 5, 35, 3): 0.0,
#  (2, 2, 22, 1): 0.0,
#  (1, 1, 10, 1): 0.0,
#  (1, 5, 23, 3): 0.0,
#  (4, 4, 15, 1): 0.0,
#  (1, 3, 2, 1): 0.0,
#  (1, 3, 32, 2): 0.0,
#  (3, 5, 35, 3): 0.0,
#  (5, 2, 9, 1): 0.0,
#  (1, 2, 42, 3): 0.0,
#  (2, 1, 29, 3): 0.0,
#  (5, 5, 40, 2): 0.0,
#  (3, 4, 20, 3): 0.0,
#  (5, 1, 5, 2): 0.0,
#  (5, 1, 39, 1): 0.0,
#  (5, 4, 23, 2): 0.0,
#  (4, 5, 29, 1): 0.0,
#  (1, 4, 20, 1): 0.0,
#  (3, 1, 27, 3): 0.0,
#  (1, 3, 29, 2): 0.0,
#  (4, 2, 44, 3): 0.0,
#  (3, 5, 22, 2): 0.0,
#  (2, 5, 45, 3): 0.0,
#  (1, 2, 39, 2): 0.0,
#  (5, 5, 23, 1): 0.0,
#  (4, 3, 19, 3): 0.0,
#  (3, 4, 25, 2): 0.0,
#  (5, 1, 8, 3): 0.0,
#  (2, 2, 13, 3): 0.0,
#  (5, 4, 34, 2): 0.0,
#  (4, 5, 40, 3): 0.0,
#  (4, 1, 37, 2): 0.0,
#  (3, 2, 43, 1): 0.0,
#  (1, 4, 25, 2): 0.0,
#  (2, 4, 41, 2): 0.0,
#  (1, 3, 35, 3): 0.0,
#  (3, 5, 25, 1): 0.0,
#  (2, 1, 39, 1): 0.0,
#  (2, 1, 6, 1): 0.0,
#  (3, 4, 44, 2): 0.0,
#  (2, 2, 10, 2): 0.0,
#  (3, 3, 5, 1): 0.0,
#  (5, 4, 20, 3): 0.0,
#  (1, 5, 45, 1): 0.0,
#  (2, 3, 29, 2): 0.0,
#  (5, 3, 5, 3): 0.0,
#  (2, 4, 36, 3): 0.0,
#  (4, 2, 6, 1): 0.0,
#  (3, 5, 34, 1): 0.0,
#  (5, 5, 9, 2): 0.0,
#  (3, 2, 36, 1): 0.0,
#  (1, 2, 43, 1): 0.0,
#  (1, 2, 9, 2): 0.0,
#  (4, 3, 16, 2): 0.0,
#  (3, 4, 26, 3): 0.0,
#  (5, 5, 43, 2): 0.0,
#  (4, 4, 17, 3): 0.0,
#  (2, 2, 29, 1): 0.0,
#  (5, 1, 38, 3): 0.0,
#  (3, 3, 18, 1): 0.0,
#  (5, 4, 1, 2): 0.0,
#  (4, 1, 38, 3): 0.0,
#  (5, 5, 35, 2): 0.0,
#  (2, 4, 17, 1): 0.0,
#  (1, 3, 9, 1): 0.0,
#  (3, 1, 26, 1): 0.0,
#  (3, 5, 21, 2): 0.0,
#  (5, 2, 6, 1): 0.0,
#  (1, 2, 36, 2): 0.0,
#  (4, 3, 5, 3): 0.0,
#  (3, 4, 15, 2): 0.0,
#  (5, 5, 22, 3): 0.0,
#  (4, 4, 28, 2): 0.0,
#  (5, 4, 44, 2): 0.0,
#  (5, 4, 14, 1): 0.0,
#  (4, 5, 18, 1): 0.0,
#  (4, 1, 43, 2): 0.0,
#  ...}

# %%
model.Ypipeline.get_values()
# Out:
# {(1, 1): 0.0,
#  (1, 2): 1.0,
#  (1, 3): 1.0,
#  (1, 4): 1.0,
#  (1, 5): 1.0,
#  (2, 1): 0.0,
#  (2, 2): 0.0,
#  (2, 3): 1.0,
#  (2, 4): 1.0,
#  (2, 5): 0.0,
#  (3, 1): 0.0,
#  (3, 2): 0.0,
#  (3, 3): 0.0,
#  (3, 4): 1.0,
#  (3, 5): 1.0,
#  (4, 1): 0.0,
#  (4, 2): 0.0,
#  (4, 3): 0.0,
#  (4, 4): 0.0,
#  (4, 5): 0.0,
#  (5, 1): 0.0,
#  (5, 2): 1.0,
#  (5, 3): 0.0,
#  (5, 4): 1.0,
#  (5, 5): 0.0}

# %%
P_matrix=np.zeros(shape=(DemandData.shape[0],Technologies.shape[1]+1))
for i in range(1,DemandData.shape[0]+1):
    for j in range(1,Technologies.shape[1]+1+1):
        P_matrix[i-1,j-1]=model.P[i,j].value

# %%
P=pd.DataFrame(P_matrix)
